# %%
import json
with open("results_dict_ner_tag.json", "r", encoding='utf-8') as f:
     results_dict = json.load(f)

# %%
from collections import Counter

# Initialize a dictionary to store phrase frequencies for each file
phrase_freq_dict = {}

# Define the specific phrases we care about
phrases_we_care = {"印度"}

# Define the tags we care about
tags_we_care = {'LOC', 'NORP', 'GPE'}

total_freq_across_files = {phrase: 0 for phrase in phrases_we_care}

# Iterate over each file in the results_dict
for file_name, file_data in results_dict.items():
    # Extract all_tags from the file data
    all_tags = file_data.get('all_tags', [])
    
    # Count the frequency of each specific phrase (only for tags in tags_we_care)
    phrase_counter = Counter(
        phrase for phrase, tag, _, _ in all_tags
        if tag in tags_we_care and phrase in phrases_we_care
    )
    
    # Store the phrase frequencies in the dictionary
    phrase_freq_dict[file_name] = {
        'phrase_freq': dict(phrase_counter),
        'total_freq': sum(phrase_counter.values())  # Sum of all phrase frequencies
    }

# Sort files by the total frequency of phrases (descending order)
sorted_files = sorted(phrase_freq_dict.items(), key=lambda x: x[1]['total_freq'], reverse=True)

# Print the results
for file_name, data in sorted_files:
    print(f"File: {file_name}")
    print("Phrase Frequencies:")
    for phrase in phrases_we_care:
        freq = data['phrase_freq'].get(phrase, 0)  # Get frequency or 0 if phrase not found
        print(f"  {phrase}: {freq}")
    print(f"Total Frequency: {data['total_freq']}")
    print("-" * 40)  # Separator for readability
# Out:
# File: 海上逸史.txt
# Phrase Frequencies:
#   印度: 10
# Total Frequency: 10
# ----------------------------------------
# File: 月球殖民地小說.txt
# Phrase Frequencies:
#   印度: 4
# Total Frequency: 4
# ----------------------------------------
# File: 狮子血.txt
# Phrase Frequencies:
#   印度: 2
# Total Frequency: 2
# ----------------------------------------
# File: 探险英雄传.txt
# Phrase Frequencies:
#   印度: 1
# Total Frequency: 1
# ----------------------------------------
# File: 不可思议.txt
# Phrase Frequencies:
#   印度: 0
# Total Frequency: 0
# ----------------------------------------
# File: 中央亚非利加之蛮地探险.txt
# Phrase Frequencies:
#   印度: 0
# Total Frequency: 0
# ----------------------------------------
# File: 冒险夜行.txt
# Phrase Frequencies:
#   印度: 0
# Total Frequency: 0
# ----------------------------------------
# File: 冒险奇谈.txt
# Phrase Frequencies:
#   印度: 0
# Total Frequency: 0
# ----------------------------------------
# File: 冒险小说孤店村.txt
# Phrase Frequencies:
#   印度: 0
# Total Frequency: 0
# ----------------------------------------
# File: 冒险小说柏麦船长航海谈.txt
# Phrase Frequencies:
#   印度: 0
# Total Frequency: 0
# ----------------------------------------
# File: 冒险小说火山岛.txt
# Phrase Frequencies:
#   印度: 0
# Total Frequency: 0
# ----------------------------------------
# File: 冒险小说航海家儿.txt
# Phrase Frequencies:
#   印度: 0
# Total Frequency: 0
# ----------------------------------------
# File: 冒险小说金沙窟.txt
# Phrase Frequencies:
#   印度: 0
# Total Frequency: 0
# ----------------------------------------
# File: 冒险小说鬼域.txt
# Phrase Frequencies:
#   印度: 0
# Total Frequency: 0
# ----------------------------------------
# File: 冒险成功之商界伟人.txt
# Phrase Frequencies:
#   印度: 0
# Total Frequency: 0
# ----------------------------------------
# File: 冢中怪.txt
# Phrase Frequencies:
#   印度: 0
# Total Frequency: 0
# ----------------------------------------
# File: 北冰洋归客谈.txt
# Phrase Frequencies:
#   印度: 0
# Total Frequency: 0
# ----------------------------------------
# File: 南斐洲脱险记.txt
# Phrase Frequencies:
#   印度: 0
# Total Frequency: 0
# ----------------------------------------
# File: 叶兰.txt
# Phrase Frequencies:
#   印度: 0
# Total Frequency: 0
# ----------------------------------------
# File: 司宾洛.txt
# Phrase Frequencies:
#   印度: 0
# Total Frequency: 0
# ----------------------------------------
# File: 回风.txt
# Phrase Frequencies:
#   印度: 0
# Total Frequency: 0
# ----------------------------------------
# File: 地下都会与海底森林.txt
# Phrase Frequencies:
#   印度: 0
# Total Frequency: 0
# ----------------------------------------
# File: 女丈夫.txt
# Phrase Frequencies:
#   印度: 0
# Total Frequency: 0
# ----------------------------------------
# File: 小中华.txt
# Phrase Frequencies:
#   印度: 0
# Total Frequency: 0
# ----------------------------------------
# File: 岛国归婚记.txt
# Phrase Frequencies:
#   印度: 0
# Total Frequency: 0
# ----------------------------------------
# File: 弟.txt
# Phrase Frequencies:
#   印度: 0
# Total Frequency: 0
# ----------------------------------------
# File: 怪国探险记.txt
# Phrase Frequencies:
#   印度: 0
# Total Frequency: 0
# ----------------------------------------
# File: 新殖民地仲尼島.txt
# Phrase Frequencies:
#   印度: 0
# Total Frequency: 0
# ----------------------------------------
# File: 树穴书.txt
# Phrase Frequencies:
#   印度: 0
# Total Frequency: 0
# ----------------------------------------
# File: 毒洲探险记.txt
# Phrase Frequencies:
#   印度: 0
# Total Frequency: 0
# ----------------------------------------
# File: 海底奇谈.txt
# Phrase Frequencies:
#   印度: 0
# Total Frequency: 0
# ----------------------------------------
# File: 渔父冒险记 冠万.txt
# Phrase Frequencies:
#   印度: 0
# Total Frequency: 0
# ----------------------------------------
# File: 渔父冒险记 孙明兴.txt
# Phrase Frequencies:
#   印度: 0
# Total Frequency: 0
# ----------------------------------------
# File: 渔父冒险记 林远隆.txt
# Phrase Frequencies:
#   印度: 0
# Total Frequency: 0
# ----------------------------------------
# File: 渔父冒险记 黄荣仙.txt
# Phrase Frequencies:
#   印度: 0
# Total Frequency: 0
# ----------------------------------------
# File: 滕半仙伝.txt
# Phrase Frequencies:
#   印度: 0
# Total Frequency: 0
# ----------------------------------------
# File: 片帆影.txt
# Phrase Frequencies:
#   印度: 0
# Total Frequency: 0
# ----------------------------------------
# File: 狼吻余生记.txt
# Phrase Frequencies:
#   印度: 0
# Total Frequency: 0
# ----------------------------------------
# File: 百斯笃殖民政策记.txt
# Phrase Frequencies:
#   印度: 0
# Total Frequency: 0
# ----------------------------------------
# File: 盗盗.txt
# Phrase Frequencies:
#   印度: 0
# Total Frequency: 0
# ----------------------------------------
# File: 破舟遇险记.txt
# Phrase Frequencies:
#   印度: 0
# Total Frequency: 0
# ----------------------------------------
# File: 磊落士官.txt
# Phrase Frequencies:
#   印度: 0
# Total Frequency: 0
# ----------------------------------------
# File: 穴居.txt
# Phrase Frequencies:
#   印度: 0
# Total Frequency: 0
# ----------------------------------------
# File: 空中岛.txt
# Phrase Frequencies:
#   印度: 0
# Total Frequency: 0
# ----------------------------------------
# File: 纪实冒险小说洞庭湖.txt
# Phrase Frequencies:
#   印度: 0
# Total Frequency: 0
# ----------------------------------------
# File: 航海奇遇.txt
# Phrase Frequencies:
#   印度: 0
# Total Frequency: 0
# ----------------------------------------
# File: 航船盗.txt
# Phrase Frequencies:
#   印度: 0
# Total Frequency: 0
# ----------------------------------------
# File: 英男孝女记.txt
# Phrase Frequencies:
#   印度: 0
# Total Frequency: 0
# ----------------------------------------
# File: 荒岛孤踪.txt
# Phrase Frequencies:
#   印度: 0
# Total Frequency: 0
# ----------------------------------------
# File: 荒岛漂泊记.txt
# Phrase Frequencies:
#   印度: 0
# Total Frequency: 0
# ----------------------------------------
# File: 蛇虎斗.txt
# Phrase Frequencies:
#   印度: 0
# Total Frequency: 0
# ----------------------------------------
# File: 记事小说虎口余生记.txt
# Phrase Frequencies:
#   印度: 0
# Total Frequency: 0
# ----------------------------------------
# File: 陆治斯南极探险事.txt
# Phrase Frequencies:
#   印度: 0
# Total Frequency: 0
# ----------------------------------------
# File: 青铜钱.txt
# Phrase Frequencies:
#   印度: 0
# Total Frequency: 0
# ----------------------------------------
# File: 非洲探险记.txt
# Phrase Frequencies:
#   印度: 0
# Total Frequency: 0
# ----------------------------------------
# File: 革命党.txt
# Phrase Frequencies:
#   印度: 0
# Total Frequency: 0
# ----------------------------------------
# File: 驮轮御风记.txt
# Phrase Frequencies:
#   印度: 0
# Total Frequency: 0
# ----------------------------------------
# File: 魔窟.txt
# Phrase Frequencies:
#   印度: 0
# Total Frequency: 0
# ----------------------------------------
# File: 鱼丽水历险记.txt
# Phrase Frequencies:
#   印度: 0
# Total Frequency: 0
# ----------------------------------------
# File: 鸭蛋岛探险记.txt
# Phrase Frequencies:
#   印度: 0
# Total Frequency: 0
# ----------------------------------------

# %%
from collections import Counter

# Initialize a dictionary to store phrase frequencies for each file
phrase_freq_dict = {}

# Define the specific phrases we care about
phrases_we_care = {"英國", "英倫", "英吉利","英"}

# Define the tags we care about
tags_we_care = {'LOC', 'NORP', 'GPE'}

# Initialize a dictionary to store the sum of frequencies across all files
total_freq_across_files = {phrase: 0 for phrase in phrases_we_care}

files_with_phrases = 0

# Iterate over each file in the results_dict
for file_name, file_data in results_dict.items():
    # Extract all_tags from the file data
    all_tags = file_data.get('all_tags', [])
    
    # Count the frequency of each specific phrase (only for tags in tags_we_care)
    phrase_counter = Counter(
        phrase for phrase, tag, _, _ in all_tags
        if tag in tags_we_care and phrase in phrases_we_care
    )
    
    if phrase_counter:
        files_with_phrases += 1
    
    # Store the phrase frequencies in the dictionary
    phrase_freq_dict[file_name] = {
        'phrase_freq': dict(phrase_counter),
        'total_freq': sum(phrase_counter.values())  # Sum of all phrase frequencies
    }
    
    # Update the total frequency across all files
    for phrase, freq in phrase_counter.items():
        total_freq_across_files[phrase] += freq

# Sort files by the total frequency of phrases (descending order)
sorted_files = sorted(phrase_freq_dict.items(), key=lambda x: x[1]['total_freq'], reverse=True)

# Print the results for each file
for file_name, data in sorted_files:
    print(f"File: {file_name}")
    print("Phrase Frequencies:")
    for phrase in phrases_we_care:
        freq = data['phrase_freq'].get(phrase, 0)  # Get frequency or 0 if phrase not found
        print(f"  {phrase}: {freq}")
    print(f"Total Frequency: {data['total_freq']}")
    print("-" * 40)  # Separator for readability

# Print the sum of frequencies across all files
print("Sum of Frequencies Across All Files:")
for phrase, total_freq in total_freq_across_files.items():
    print(f"  {phrase}: {total_freq}")

print(f"\nNumber of files containing at least one of the phrases: {files_with_phrases}")
# Out:
# File: 月球殖民地小說.txt
# Phrase Frequencies:
#   英吉利: 0
#   英倫: 0
#   英國: 32
#   英: 1
# Total Frequency: 33
# ----------------------------------------
# File: 中央亚非利加之蛮地探险.txt
# Phrase Frequencies:
#   英吉利: 0
#   英倫: 0
#   英國: 4
#   英: 1
# Total Frequency: 5
# ----------------------------------------
# File: 叶兰.txt
# Phrase Frequencies:
#   英吉利: 0
#   英倫: 0
#   英國: 0
#   英: 4
# Total Frequency: 4
# ----------------------------------------
# File: 女丈夫.txt
# Phrase Frequencies:
#   英吉利: 0
#   英倫: 0
#   英國: 3
#   英: 1
# Total Frequency: 4
# ----------------------------------------
# File: 非洲探险记.txt
# Phrase Frequencies:
#   英吉利: 0
#   英倫: 0
#   英國: 4
#   英: 0
# Total Frequency: 4
# ----------------------------------------
# File: 冒险成功之商界伟人.txt
# Phrase Frequencies:
#   英吉利: 0
#   英倫: 0
#   英國: 2
#   英: 1
# Total Frequency: 3
# ----------------------------------------
# File: 革命党.txt
# Phrase Frequencies:
#   英吉利: 0
#   英倫: 0
#   英國: 3
#   英: 0
# Total Frequency: 3
# ----------------------------------------
# File: 冒险小说柏麦船长航海谈.txt
# Phrase Frequencies:
#   英吉利: 0
#   英倫: 1
#   英國: 0
#   英: 1
# Total Frequency: 2
# ----------------------------------------
# File: 冢中怪.txt
# Phrase Frequencies:
#   英吉利: 0
#   英倫: 0
#   英國: 0
#   英: 2
# Total Frequency: 2
# ----------------------------------------
# File: 探险英雄传.txt
# Phrase Frequencies:
#   英吉利: 0
#   英倫: 0
#   英國: 0
#   英: 2
# Total Frequency: 2
# ----------------------------------------
# File: 海上逸史.txt
# Phrase Frequencies:
#   英吉利: 0
#   英倫: 0
#   英國: 2
#   英: 0
# Total Frequency: 2
# ----------------------------------------
# File: 冒险小说航海家儿.txt
# Phrase Frequencies:
#   英吉利: 0
#   英倫: 1
#   英國: 0
#   英: 0
# Total Frequency: 1
# ----------------------------------------
# File: 南斐洲脱险记.txt
# Phrase Frequencies:
#   英吉利: 0
#   英倫: 0
#   英國: 1
#   英: 0
# Total Frequency: 1
# ----------------------------------------
# File: 地下都会与海底森林.txt
# Phrase Frequencies:
#   英吉利: 0
#   英倫: 0
#   英國: 1
#   英: 0
# Total Frequency: 1
# ----------------------------------------
# File: 岛国归婚记.txt
# Phrase Frequencies:
#   英吉利: 0
#   英倫: 0
#   英國: 0
#   英: 1
# Total Frequency: 1
# ----------------------------------------
# File: 弟.txt
# Phrase Frequencies:
#   英吉利: 0
#   英倫: 0
#   英國: 0
#   英: 1
# Total Frequency: 1
# ----------------------------------------
# File: 树穴书.txt
# Phrase Frequencies:
#   英吉利: 0
#   英倫: 0
#   英國: 0
#   英: 1
# Total Frequency: 1
# ----------------------------------------
# File: 英男孝女记.txt
# Phrase Frequencies:
#   英吉利: 0
#   英倫: 0
#   英國: 0
#   英: 1
# Total Frequency: 1
# ----------------------------------------
# File: 陆治斯南极探险事.txt
# Phrase Frequencies:
#   英吉利: 0
#   英倫: 0
#   英國: 1
#   英: 0
# Total Frequency: 1
# ----------------------------------------
# File: 鱼丽水历险记.txt
# Phrase Frequencies:
#   英吉利: 0
#   英倫: 0
#   英國: 0
#   英: 1
# Total Frequency: 1
# ----------------------------------------
# File: 不可思议.txt
# Phrase Frequencies:
#   英吉利: 0
#   英倫: 0
#   英國: 0
#   英: 0
# Total Frequency: 0
# ----------------------------------------
# File: 冒险夜行.txt
# Phrase Frequencies:
#   英吉利: 0
#   英倫: 0
#   英國: 0
#   英: 0
# Total Frequency: 0
# ----------------------------------------
# File: 冒险奇谈.txt
# Phrase Frequencies:
#   英吉利: 0
#   英倫: 0
#   英國: 0
#   英: 0
# Total Frequency: 0
# ----------------------------------------
# File: 冒险小说孤店村.txt
# Phrase Frequencies:
#   英吉利: 0
#   英倫: 0
#   英國: 0
#   英: 0
# Total Frequency: 0
# ----------------------------------------
# File: 冒险小说火山岛.txt
# Phrase Frequencies:
#   英吉利: 0
#   英倫: 0
#   英國: 0
#   英: 0
# Total Frequency: 0
# ----------------------------------------
# File: 冒险小说金沙窟.txt
# Phrase Frequencies:
#   英吉利: 0
#   英倫: 0
#   英國: 0
#   英: 0
# Total Frequency: 0
# ----------------------------------------
# File: 冒险小说鬼域.txt
# Phrase Frequencies:
#   英吉利: 0
#   英倫: 0
#   英國: 0
#   英: 0
# Total Frequency: 0
# ----------------------------------------
# File: 北冰洋归客谈.txt
# Phrase Frequencies:
#   英吉利: 0
#   英倫: 0
#   英國: 0
#   英: 0
# Total Frequency: 0
# ----------------------------------------
# File: 司宾洛.txt
# Phrase Frequencies:
#   英吉利: 0
#   英倫: 0
#   英國: 0
#   英: 0
# Total Frequency: 0
# ----------------------------------------
# File: 回风.txt
# Phrase Frequencies:
#   英吉利: 0
#   英倫: 0
#   英國: 0
#   英: 0
# Total Frequency: 0
# ----------------------------------------
# File: 小中华.txt
# Phrase Frequencies:
#   英吉利: 0
#   英倫: 0
#   英國: 0
#   英: 0
# Total Frequency: 0
# ----------------------------------------
# File: 怪国探险记.txt
# Phrase Frequencies:
#   英吉利: 0
#   英倫: 0
#   英國: 0
#   英: 0
# Total Frequency: 0
# ----------------------------------------
# File: 新殖民地仲尼島.txt
# Phrase Frequencies:
#   英吉利: 0
#   英倫: 0
#   英國: 0
#   英: 0
# Total Frequency: 0
# ----------------------------------------
# File: 毒洲探险记.txt
# Phrase Frequencies:
#   英吉利: 0
#   英倫: 0
#   英國: 0
#   英: 0
# Total Frequency: 0
# ----------------------------------------
# File: 海底奇谈.txt
# Phrase Frequencies:
#   英吉利: 0
#   英倫: 0
#   英國: 0
#   英: 0
# Total Frequency: 0
# ----------------------------------------
# File: 渔父冒险记 冠万.txt
# Phrase Frequencies:
#   英吉利: 0
#   英倫: 0
#   英國: 0
#   英: 0
# Total Frequency: 0
# ----------------------------------------
# File: 渔父冒险记 孙明兴.txt
# Phrase Frequencies:
#   英吉利: 0
#   英倫: 0
#   英國: 0
#   英: 0
# Total Frequency: 0
# ----------------------------------------
# File: 渔父冒险记 林远隆.txt
# Phrase Frequencies:
#   英吉利: 0
#   英倫: 0
#   英國: 0
#   英: 0
# Total Frequency: 0
# ----------------------------------------
# File: 渔父冒险记 黄荣仙.txt
# Phrase Frequencies:
#   英吉利: 0
#   英倫: 0
#   英國: 0
#   英: 0
# Total Frequency: 0
# ----------------------------------------
# File: 滕半仙伝.txt
# Phrase Frequencies:
#   英吉利: 0
#   英倫: 0
#   英國: 0
#   英: 0
# Total Frequency: 0
# ----------------------------------------
# File: 片帆影.txt
# Phrase Frequencies:
#   英吉利: 0
#   英倫: 0
#   英國: 0
#   英: 0
# Total Frequency: 0
# ----------------------------------------
# File: 狮子血.txt
# Phrase Frequencies:
#   英吉利: 0
#   英倫: 0
#   英國: 0
#   英: 0
# Total Frequency: 0
# ----------------------------------------
# File: 狼吻余生记.txt
# Phrase Frequencies:
#   英吉利: 0
#   英倫: 0
#   英國: 0
#   英: 0
# Total Frequency: 0
# ----------------------------------------
# File: 百斯笃殖民政策记.txt
# Phrase Frequencies:
#   英吉利: 0
#   英倫: 0
#   英國: 0
#   英: 0
# Total Frequency: 0
# ----------------------------------------
# File: 盗盗.txt
# Phrase Frequencies:
#   英吉利: 0
#   英倫: 0
#   英國: 0
#   英: 0
# Total Frequency: 0
# ----------------------------------------
# File: 破舟遇险记.txt
# Phrase Frequencies:
#   英吉利: 0
#   英倫: 0
#   英國: 0
#   英: 0
# Total Frequency: 0
# ----------------------------------------
# File: 磊落士官.txt
# Phrase Frequencies:
#   英吉利: 0
#   英倫: 0
#   英國: 0
#   英: 0
# Total Frequency: 0
# ----------------------------------------
# File: 穴居.txt
# Phrase Frequencies:
#   英吉利: 0
#   英倫: 0
#   英國: 0
#   英: 0
# Total Frequency: 0
# ----------------------------------------
# File: 空中岛.txt
# Phrase Frequencies:
#   英吉利: 0
#   英倫: 0
#   英國: 0
#   英: 0
# Total Frequency: 0
# ----------------------------------------
# File: 纪实冒险小说洞庭湖.txt
# Phrase Frequencies:
#   英吉利: 0
#   英倫: 0
#   英國: 0
#   英: 0
# Total Frequency: 0
# ----------------------------------------
# File: 航海奇遇.txt
# Phrase Frequencies:
#   英吉利: 0
#   英倫: 0
#   英國: 0
#   英: 0
# Total Frequency: 0
# ----------------------------------------
# File: 航船盗.txt
# Phrase Frequencies:
#   英吉利: 0
#   英倫: 0
#   英國: 0
#   英: 0
# Total Frequency: 0
# ----------------------------------------
# File: 荒岛孤踪.txt
# Phrase Frequencies:
#   英吉利: 0
#   英倫: 0
#   英國: 0
#   英: 0
# Total Frequency: 0
# ----------------------------------------
# File: 荒岛漂泊记.txt
# Phrase Frequencies:
#   英吉利: 0
#   英倫: 0
#   英國: 0
#   英: 0
# Total Frequency: 0
# ----------------------------------------
# File: 蛇虎斗.txt
# Phrase Frequencies:
#   英吉利: 0
#   英倫: 0
#   英國: 0
#   英: 0
# Total Frequency: 0
# ----------------------------------------
# File: 记事小说虎口余生记.txt
# Phrase Frequencies:
#   英吉利: 0
#   英倫: 0
#   英國: 0
#   英: 0
# Total Frequency: 0
# ----------------------------------------
# File: 青铜钱.txt
# Phrase Frequencies:
#   英吉利: 0
#   英倫: 0
#   英國: 0
#   英: 0
# Total Frequency: 0
# ----------------------------------------
# File: 驮轮御风记.txt
# Phrase Frequencies:
#   英吉利: 0
#   英倫: 0
#   英國: 0
#   英: 0
# Total Frequency: 0
# ----------------------------------------
# File: 魔窟.txt
# Phrase Frequencies:
#   英吉利: 0
#   英倫: 0
#   英國: 0
#   英: 0
# Total Frequency: 0
# ----------------------------------------
# File: 鸭蛋岛探险记.txt
# Phrase Frequencies:
#   英吉利: 0
#   英倫: 0
#   英國: 0
#   英: 0
# Total Frequency: 0
# ----------------------------------------
# Sum of Frequencies Across All Files:
#   英吉利: 0
#   英倫: 2
#   英國: 53
#   英: 18
#
# Number of files containing at least one of the phrases: 20

# %%
from collections import Counter

# Initialize a dictionary to store phrase frequencies for each file
phrase_freq_dict = {}

# Define the specific phrases we care about
phrases_we_care = {"中國", "中華", "支那","中","中華民國","神洲"}

# Define the tags we care about
tags_we_care = {'LOC', 'NORP', 'GPE'}

# Initialize a dictionary to store the sum of frequencies across all files
total_freq_across_files = {phrase: 0 for phrase in phrases_we_care}

files_with_phrases = 0

# Iterate over each file in the results_dict
for file_name, file_data in results_dict.items():
    # Extract all_tags from the file data
    all_tags = file_data.get('all_tags', [])
    
    # Count the frequency of each specific phrase (only for tags in tags_we_care)
    phrase_counter = Counter(
        phrase for phrase, tag, _, _ in all_tags
        if tag in tags_we_care and phrase in phrases_we_care
    )
    
    if phrase_counter:
        files_with_phrases += 1
    
    # Store the phrase frequencies in the dictionary
    phrase_freq_dict[file_name] = {
        'phrase_freq': dict(phrase_counter),
        'total_freq': sum(phrase_counter.values())  # Sum of all phrase frequencies
    }
    
    # Update the total frequency across all files
    for phrase, freq in phrase_counter.items():
        total_freq_across_files[phrase] += freq

# Sort files by the total frequency of phrases (descending order)
sorted_files = sorted(phrase_freq_dict.items(), key=lambda x: x[1]['total_freq'], reverse=True)

# Print the results for each file
for file_name, data in sorted_files:
    print(f"File: {file_name}")
    print("Phrase Frequencies:")
    for phrase in phrases_we_care:
        freq = data['phrase_freq'].get(phrase, 0)  # Get frequency or 0 if phrase not found
        print(f"  {phrase}: {freq}")
    print(f"Total Frequency: {data['total_freq']}")
    print("-" * 40)  # Separator for readability

# Print the sum of frequencies across all files
print("Sum of Frequencies Across All Files:")
for phrase, total_freq in total_freq_across_files.items():
    print(f"  {phrase}: {total_freq}")
    
print(f"\nNumber of files containing at least one of the phrases: {files_with_phrases}")
# Out:
# File: 月球殖民地小說.txt
# Phrase Frequencies:
#   神洲: 0
#   中華: 0
#   支那: 0
#   中華民國: 0
#   中: 0
#   中國: 133
# Total Frequency: 133
# ----------------------------------------
# File: 革命党.txt
# Phrase Frequencies:
#   神洲: 0
#   中華: 0
#   支那: 0
#   中華民國: 0
#   中: 0
#   中國: 37
# Total Frequency: 37
# ----------------------------------------
# File: 女丈夫.txt
# Phrase Frequencies:
#   神洲: 0
#   中華: 0
#   支那: 0
#   中華民國: 0
#   中: 0
#   中國: 23
# Total Frequency: 23
# ----------------------------------------
# File: 冒险成功之商界伟人.txt
# Phrase Frequencies:
#   神洲: 0
#   中華: 0
#   支那: 0
#   中華民國: 0
#   中: 0
#   中國: 21
# Total Frequency: 21
# ----------------------------------------
# File: 小中华.txt
# Phrase Frequencies:
#   神洲: 0
#   中華: 14
#   支那: 0
#   中華民國: 0
#   中: 0
#   中國: 0
# Total Frequency: 14
# ----------------------------------------
# File: 狮子血.txt
# Phrase Frequencies:
#   神洲: 0
#   中華: 0
#   支那: 7
#   中華民國: 0
#   中: 1
#   中國: 6
# Total Frequency: 14
# ----------------------------------------
# File: 探险英雄传.txt
# Phrase Frequencies:
#   神洲: 0
#   中華: 0
#   支那: 0
#   中華民國: 0
#   中: 0
#   中國: 7
# Total Frequency: 7
# ----------------------------------------
# File: 怪国探险记.txt
# Phrase Frequencies:
#   神洲: 0
#   中華: 5
#   支那: 0
#   中華民國: 0
#   中: 0
#   中國: 1
# Total Frequency: 6
# ----------------------------------------
# File: 毒洲探险记.txt
# Phrase Frequencies:
#   神洲: 1
#   中華: 0
#   支那: 0
#   中華民國: 0
#   中: 0
#   中國: 3
# Total Frequency: 4
# ----------------------------------------
# File: 叶兰.txt
# Phrase Frequencies:
#   神洲: 0
#   中華: 0
#   支那: 0
#   中華民國: 0
#   中: 2
#   中國: 0
# Total Frequency: 2
# ----------------------------------------
# File: 鱼丽水历险记.txt
# Phrase Frequencies:
#   神洲: 0
#   中華: 0
#   支那: 0
#   中華民國: 0
#   中: 0
#   中國: 2
# Total Frequency: 2
# ----------------------------------------
# File: 不可思议.txt
# Phrase Frequencies:
#   神洲: 0
#   中華: 0
#   支那: 0
#   中華民國: 1
#   中: 0
#   中國: 0
# Total Frequency: 1
# ----------------------------------------
# File: 冒险小说柏麦船长航海谈.txt
# Phrase Frequencies:
#   神洲: 0
#   中華: 0
#   支那: 1
#   中華民國: 0
#   中: 0
#   中國: 0
# Total Frequency: 1
# ----------------------------------------
# File: 冒险小说航海家儿.txt
# Phrase Frequencies:
#   神洲: 0
#   中華: 1
#   支那: 0
#   中華民國: 0
#   中: 0
#   中國: 0
# Total Frequency: 1
# ----------------------------------------
# File: 海底奇谈.txt
# Phrase Frequencies:
#   神洲: 0
#   中華: 0
#   支那: 0
#   中華民國: 0
#   中: 1
#   中國: 0
# Total Frequency: 1
# ----------------------------------------
# File: 记事小说虎口余生记.txt
# Phrase Frequencies:
#   神洲: 0
#   中華: 0
#   支那: 0
#   中華民國: 0
#   中: 0
#   中國: 1
# Total Frequency: 1
# ----------------------------------------
# File: 驮轮御风记.txt
# Phrase Frequencies:
#   神洲: 0
#   中華: 0
#   支那: 0
#   中華民國: 0
#   中: 0
#   中國: 1
# Total Frequency: 1
# ----------------------------------------
# File: 鸭蛋岛探险记.txt
# Phrase Frequencies:
#   神洲: 0
#   中華: 0
#   支那: 0
#   中華民國: 0
#   中: 0
#   中國: 1
# Total Frequency: 1
# ----------------------------------------
# File: 中央亚非利加之蛮地探险.txt
# Phrase Frequencies:
#   神洲: 0
#   中華: 0
#   支那: 0
#   中華民國: 0
#   中: 0
#   中國: 0
# Total Frequency: 0
# ----------------------------------------
# File: 冒险夜行.txt
# Phrase Frequencies:
#   神洲: 0
#   中華: 0
#   支那: 0
#   中華民國: 0
#   中: 0
#   中國: 0
# Total Frequency: 0
# ----------------------------------------
# File: 冒险奇谈.txt
# Phrase Frequencies:
#   神洲: 0
#   中華: 0
#   支那: 0
#   中華民國: 0
#   中: 0
#   中國: 0
# Total Frequency: 0
# ----------------------------------------
# File: 冒险小说孤店村.txt
# Phrase Frequencies:
#   神洲: 0
#   中華: 0
#   支那: 0
#   中華民國: 0
#   中: 0
#   中國: 0
# Total Frequency: 0
# ----------------------------------------
# File: 冒险小说火山岛.txt
# Phrase Frequencies:
#   神洲: 0
#   中華: 0
#   支那: 0
#   中華民國: 0
#   中: 0
#   中國: 0
# Total Frequency: 0
# ----------------------------------------
# File: 冒险小说金沙窟.txt
# Phrase Frequencies:
#   神洲: 0
#   中華: 0
#   支那: 0
#   中華民國: 0
#   中: 0
#   中國: 0
# Total Frequency: 0
# ----------------------------------------
# File: 冒险小说鬼域.txt
# Phrase Frequencies:
#   神洲: 0
#   中華: 0
#   支那: 0
#   中華民國: 0
#   中: 0
#   中國: 0
# Total Frequency: 0
# ----------------------------------------
# File: 冢中怪.txt
# Phrase Frequencies:
#   神洲: 0
#   中華: 0
#   支那: 0
#   中華民國: 0
#   中: 0
#   中國: 0
# Total Frequency: 0
# ----------------------------------------
# File: 北冰洋归客谈.txt
# Phrase Frequencies:
#   神洲: 0
#   中華: 0
#   支那: 0
#   中華民國: 0
#   中: 0
#   中國: 0
# Total Frequency: 0
# ----------------------------------------
# File: 南斐洲脱险记.txt
# Phrase Frequencies:
#   神洲: 0
#   中華: 0
#   支那: 0
#   中華民國: 0
#   中: 0
#   中國: 0
# Total Frequency: 0
# ----------------------------------------
# File: 司宾洛.txt
# Phrase Frequencies:
#   神洲: 0
#   中華: 0
#   支那: 0
#   中華民國: 0
#   中: 0
#   中國: 0
# Total Frequency: 0
# ----------------------------------------
# File: 回风.txt
# Phrase Frequencies:
#   神洲: 0
#   中華: 0
#   支那: 0
#   中華民國: 0
#   中: 0
#   中國: 0
# Total Frequency: 0
# ----------------------------------------
# File: 地下都会与海底森林.txt
# Phrase Frequencies:
#   神洲: 0
#   中華: 0
#   支那: 0
#   中華民國: 0
#   中: 0
#   中國: 0
# Total Frequency: 0
# ----------------------------------------
# File: 岛国归婚记.txt
# Phrase Frequencies:
#   神洲: 0
#   中華: 0
#   支那: 0
#   中華民國: 0
#   中: 0
#   中國: 0
# Total Frequency: 0
# ----------------------------------------
# File: 弟.txt
# Phrase Frequencies:
#   神洲: 0
#   中華: 0
#   支那: 0
#   中華民國: 0
#   中: 0
#   中國: 0
# Total Frequency: 0
# ----------------------------------------
# File: 新殖民地仲尼島.txt
# Phrase Frequencies:
#   神洲: 0
#   中華: 0
#   支那: 0
#   中華民國: 0
#   中: 0
#   中國: 0
# Total Frequency: 0
# ----------------------------------------
# File: 树穴书.txt
# Phrase Frequencies:
#   神洲: 0
#   中華: 0
#   支那: 0
#   中華民國: 0
#   中: 0
#   中國: 0
# Total Frequency: 0
# ----------------------------------------
# File: 海上逸史.txt
# Phrase Frequencies:
#   神洲: 0
#   中華: 0
#   支那: 0
#   中華民國: 0
#   中: 0
#   中國: 0
# Total Frequency: 0
# ----------------------------------------
# File: 渔父冒险记 冠万.txt
# Phrase Frequencies:
#   神洲: 0
#   中華: 0
#   支那: 0
#   中華民國: 0
#   中: 0
#   中國: 0
# Total Frequency: 0
# ----------------------------------------
# File: 渔父冒险记 孙明兴.txt
# Phrase Frequencies:
#   神洲: 0
#   中華: 0
#   支那: 0
#   中華民國: 0
#   中: 0
#   中國: 0
# Total Frequency: 0
# ----------------------------------------
# File: 渔父冒险记 林远隆.txt
# Phrase Frequencies:
#   神洲: 0
#   中華: 0
#   支那: 0
#   中華民國: 0
#   中: 0
#   中國: 0
# Total Frequency: 0
# ----------------------------------------
# File: 渔父冒险记 黄荣仙.txt
# Phrase Frequencies:
#   神洲: 0
#   中華: 0
#   支那: 0
#   中華民國: 0
#   中: 0
#   中國: 0
# Total Frequency: 0
# ----------------------------------------
# File: 滕半仙伝.txt
# Phrase Frequencies:
#   神洲: 0
#   中華: 0
#   支那: 0
#   中華民國: 0
#   中: 0
#   中國: 0
# Total Frequency: 0
# ----------------------------------------
# File: 片帆影.txt
# Phrase Frequencies:
#   神洲: 0
#   中華: 0
#   支那: 0
#   中華民國: 0
#   中: 0
#   中國: 0
# Total Frequency: 0
# ----------------------------------------
# File: 狼吻余生记.txt
# Phrase Frequencies:
#   神洲: 0
#   中華: 0
#   支那: 0
#   中華民國: 0
#   中: 0
#   中國: 0
# Total Frequency: 0
# ----------------------------------------
# File: 百斯笃殖民政策记.txt
# Phrase Frequencies:
#   神洲: 0
#   中華: 0
#   支那: 0
#   中華民國: 0
#   中: 0
#   中國: 0
# Total Frequency: 0
# ----------------------------------------
# File: 盗盗.txt
# Phrase Frequencies:
#   神洲: 0
#   中華: 0
#   支那: 0
#   中華民國: 0
#   中: 0
#   中國: 0
# Total Frequency: 0
# ----------------------------------------
# File: 破舟遇险记.txt
# Phrase Frequencies:
#   神洲: 0
#   中華: 0
#   支那: 0
#   中華民國: 0
#   中: 0
#   中國: 0
# Total Frequency: 0
# ----------------------------------------
# File: 磊落士官.txt
# Phrase Frequencies:
#   神洲: 0
#   中華: 0
#   支那: 0
#   中華民國: 0
#   中: 0
#   中國: 0
# Total Frequency: 0
# ----------------------------------------
# File: 穴居.txt
# Phrase Frequencies:
#   神洲: 0
#   中華: 0
#   支那: 0
#   中華民國: 0
#   中: 0
#   中國: 0
# Total Frequency: 0
# ----------------------------------------
# File: 空中岛.txt
# Phrase Frequencies:
#   神洲: 0
#   中華: 0
#   支那: 0
#   中華民國: 0
#   中: 0
#   中國: 0
# Total Frequency: 0
# ----------------------------------------
# File: 纪实冒险小说洞庭湖.txt
# Phrase Frequencies:
#   神洲: 0
#   中華: 0
#   支那: 0
#   中華民國: 0
#   中: 0
#   中國: 0
# Total Frequency: 0
# ----------------------------------------
# File: 航海奇遇.txt
# Phrase Frequencies:
#   神洲: 0
#   中華: 0
#   支那: 0
#   中華民國: 0
#   中: 0
#   中國: 0
# Total Frequency: 0
# ----------------------------------------
# File: 航船盗.txt
# Phrase Frequencies:
#   神洲: 0
#   中華: 0
#   支那: 0
#   中華民國: 0
#   中: 0
#   中國: 0
# Total Frequency: 0
# ----------------------------------------
# File: 英男孝女记.txt
# Phrase Frequencies:
#   神洲: 0
#   中華: 0
#   支那: 0
#   中華民國: 0
#   中: 0
#   中國: 0
# Total Frequency: 0
# ----------------------------------------
# File: 荒岛孤踪.txt
# Phrase Frequencies:
#   神洲: 0
#   中華: 0
#   支那: 0
#   中華民國: 0
#   中: 0
#   中國: 0
# Total Frequency: 0
# ----------------------------------------
# File: 荒岛漂泊记.txt
# Phrase Frequencies:
#   神洲: 0
#   中華: 0
#   支那: 0
#   中華民國: 0
#   中: 0
#   中國: 0
# Total Frequency: 0
# ----------------------------------------
# File: 蛇虎斗.txt
# Phrase Frequencies:
#   神洲: 0
#   中華: 0
#   支那: 0
#   中華民國: 0
#   中: 0
#   中國: 0
# Total Frequency: 0
# ----------------------------------------
# File: 陆治斯南极探险事.txt
# Phrase Frequencies:
#   神洲: 0
#   中華: 0
#   支那: 0
#   中華民國: 0
#   中: 0
#   中國: 0
# Total Frequency: 0
# ----------------------------------------
# File: 青铜钱.txt
# Phrase Frequencies:
#   神洲: 0
#   中華: 0
#   支那: 0
#   中華民國: 0
#   中: 0
#   中國: 0
# Total Frequency: 0
# ----------------------------------------
# File: 非洲探险记.txt
# Phrase Frequencies:
#   神洲: 0
#   中華: 0
#   支那: 0
#   中華民國: 0
#   中: 0
#   中國: 0
# Total Frequency: 0
# ----------------------------------------
# File: 魔窟.txt
# Phrase Frequencies:
#   神洲: 0
#   中華: 0
#   支那: 0
#   中華民國: 0
#   中: 0
#   中國: 0
# Total Frequency: 0
# ----------------------------------------
# Sum of Frequencies Across All Files:
#   神洲: 1
#   中華: 20
#   支那: 8
#   中華民國: 1
#   中: 4
#   中國: 236
#
# Number of files containing at least one of the phrases: 18

# %%
import csv
from collections import Counter

# Initialize a dictionary to store phrase frequencies for each file
phrase_freq_dict = {}

# Define the specific phrases we care about
phrases_we_care = {"中國", "中華", "支那", "中華民國", "神洲"}

# Define the tags we care about
tags_we_care = {'LOC', 'NORP', 'GPE'}

# Initialize a dictionary to store the sum of frequencies across all files
total_freq_across_files = {phrase: 0 for phrase in phrases_we_care}

files_with_phrases = 0

# Iterate over each file in the results_dict
for file_name, file_data in results_dict.items():
    # Extract all_tags from the file data
    all_tags = file_data.get('all_tags', [])
    
    # Count the frequency of each specific phrase (only for tags in tags_we_care)
    phrase_counter = Counter(
        phrase for phrase, tag, _, _ in all_tags
        if tag in tags_we_care and phrase in phrases_we_care
    )
    
    if phrase_counter:
        files_with_phrases += 1
    
    # Store the phrase frequencies in the dictionary
    phrase_freq_dict[file_name] = {
        'phrase_freq': dict(phrase_counter),
        'total_freq': sum(phrase_counter.values())  # Sum of all phrase frequencies
    }
    
    # Update the total frequency across all files
    for phrase, freq in phrase_counter.items():
        total_freq_across_files[phrase] += freq

# Sort files by the total frequency of phrases (descending order)
sorted_files = sorted(phrase_freq_dict.items(), key=lambda x: x[1]['total_freq'], reverse=True)

# Write results to a CSV file
with open('output.csv', mode='w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    
    # Write header
    writer.writerow(['File', *phrases_we_care, 'Total Frequency'])
    
    # Write data for each file
    for file_name, data in sorted_files:
        row = [file_name]
        for phrase in phrases_we_care:
            row.append(data['phrase_freq'].get(phrase, 0))  # Get frequency or 0 if phrase not found
        row.append(data['total_freq'])
        writer.writerow(row)
    
    # Write the sum of frequencies across all files
    writer.writerow(['Sum Across All Files', *[total_freq_across_files.get(phrase, 0) for phrase in phrases_we_care], sum(total_freq_across_files.values())])
    
    # Write the number of files containing at least one of the phrases
    writer.writerow(['Files with Phrases', files_with_phrases])

print("Results have been written to output.csv")
# Out:
# Results have been written to output.csv

# %%
from collections import Counter

# Initialize a dictionary to store phrase frequencies for each file
phrase_freq_dict = {}

# Define the specific phrases we care about
phrases_we_care = {"日本", "日本國", "日","東洋"}

# Define the tags we care about
tags_we_care = {'LOC', 'NORP', 'GPE'}

# Initialize a dictionary to store the sum of frequencies across all files
total_freq_across_files = {phrase: 0 for phrase in phrases_we_care}

# Iterate over each file in the results_dict
for file_name, file_data in results_dict.items():
    # Extract all_tags from the file data
    all_tags = file_data.get('all_tags', [])
    
    # Count the frequency of each specific phrase (only for tags in tags_we_care)
    phrase_counter = Counter(
        phrase for phrase, tag, _, _ in all_tags
        if tag in tags_we_care and phrase in phrases_we_care
    )
    
    # Store the phrase frequencies in the dictionary
    phrase_freq_dict[file_name] = {
        'phrase_freq': dict(phrase_counter),
        'total_freq': sum(phrase_counter.values())  # Sum of all phrase frequencies
    }
    
    # Update the total frequency across all files
    for phrase, freq in phrase_counter.items():
        total_freq_across_files[phrase] += freq

# Sort files by the total frequency of phrases (descending order)
sorted_files = sorted(phrase_freq_dict.items(), key=lambda x: x[1]['total_freq'], reverse=True)

# Print the results for each file
for file_name, data in sorted_files:
    print(f"File: {file_name}")
    print("Phrase Frequencies:")
    for phrase in phrases_we_care:
        freq = data['phrase_freq'].get(phrase, 0)  # Get frequency or 0 if phrase not found
        print(f"  {phrase}: {freq}")
    print(f"Total Frequency: {data['total_freq']}")
    print("-" * 40)  # Separator for readability

# Print the sum of frequencies across all files
print("Sum of Frequencies Across All Files:")
for phrase, total_freq in total_freq_across_files.items():
    print(f"  {phrase}: {total_freq}")
# Out:
# File: 革命党.txt
# Phrase Frequencies:
#   日本國: 0
#   日本: 49
#   日: 0
#   東洋: 5
# Total Frequency: 54
# ----------------------------------------
# File: 月球殖民地小說.txt
# Phrase Frequencies:
#   日本國: 3
#   日本: 26
#   日: 1
#   東洋: 4
# Total Frequency: 34
# ----------------------------------------
# File: 冒险小说航海家儿.txt
# Phrase Frequencies:
#   日本國: 0
#   日本: 2
#   日: 0
#   東洋: 0
# Total Frequency: 2
# ----------------------------------------
# File: 小中华.txt
# Phrase Frequencies:
#   日本國: 0
#   日本: 2
#   日: 0
#   東洋: 0
# Total Frequency: 2
# ----------------------------------------
# File: 探险英雄传.txt
# Phrase Frequencies:
#   日本國: 0
#   日本: 0
#   日: 2
#   東洋: 0
# Total Frequency: 2
# ----------------------------------------
# File: 女丈夫.txt
# Phrase Frequencies:
#   日本國: 0
#   日本: 1
#   日: 0
#   東洋: 0
# Total Frequency: 1
# ----------------------------------------
# File: 磊落士官.txt
# Phrase Frequencies:
#   日本國: 0
#   日本: 1
#   日: 0
#   東洋: 0
# Total Frequency: 1
# ----------------------------------------
# File: 驮轮御风记.txt
# Phrase Frequencies:
#   日本國: 0
#   日本: 1
#   日: 0
#   東洋: 0
# Total Frequency: 1
# ----------------------------------------
# File: 不可思议.txt
# Phrase Frequencies:
#   日本國: 0
#   日本: 0
#   日: 0
#   東洋: 0
# Total Frequency: 0
# ----------------------------------------
# File: 中央亚非利加之蛮地探险.txt
# Phrase Frequencies:
#   日本國: 0
#   日本: 0
#   日: 0
#   東洋: 0
# Total Frequency: 0
# ----------------------------------------
# File: 冒险夜行.txt
# Phrase Frequencies:
#   日本國: 0
#   日本: 0
#   日: 0
#   東洋: 0
# Total Frequency: 0
# ----------------------------------------
# File: 冒险奇谈.txt
# Phrase Frequencies:
#   日本國: 0
#   日本: 0
#   日: 0
#   東洋: 0
# Total Frequency: 0
# ----------------------------------------
# File: 冒险小说孤店村.txt
# Phrase Frequencies:
#   日本國: 0
#   日本: 0
#   日: 0
#   東洋: 0
# Total Frequency: 0
# ----------------------------------------
# File: 冒险小说柏麦船长航海谈.txt
# Phrase Frequencies:
#   日本國: 0
#   日本: 0
#   日: 0
#   東洋: 0
# Total Frequency: 0
# ----------------------------------------
# File: 冒险小说火山岛.txt
# Phrase Frequencies:
#   日本國: 0
#   日本: 0
#   日: 0
#   東洋: 0
# Total Frequency: 0
# ----------------------------------------
# File: 冒险小说金沙窟.txt
# Phrase Frequencies:
#   日本國: 0
#   日本: 0
#   日: 0
#   東洋: 0
# Total Frequency: 0
# ----------------------------------------
# File: 冒险小说鬼域.txt
# Phrase Frequencies:
#   日本國: 0
#   日本: 0
#   日: 0
#   東洋: 0
# Total Frequency: 0
# ----------------------------------------
# File: 冒险成功之商界伟人.txt
# Phrase Frequencies:
#   日本國: 0
#   日本: 0
#   日: 0
#   東洋: 0
# Total Frequency: 0
# ----------------------------------------
# File: 冢中怪.txt
# Phrase Frequencies:
#   日本國: 0
#   日本: 0
#   日: 0
#   東洋: 0
# Total Frequency: 0
# ----------------------------------------
# File: 北冰洋归客谈.txt
# Phrase Frequencies:
#   日本國: 0
#   日本: 0
#   日: 0
#   東洋: 0
# Total Frequency: 0
# ----------------------------------------
# File: 南斐洲脱险记.txt
# Phrase Frequencies:
#   日本國: 0
#   日本: 0
#   日: 0
#   東洋: 0
# Total Frequency: 0
# ----------------------------------------
# File: 叶兰.txt
# Phrase Frequencies:
#   日本國: 0
#   日本: 0
#   日: 0
#   東洋: 0
# Total Frequency: 0
# ----------------------------------------
# File: 司宾洛.txt
# Phrase Frequencies:
#   日本國: 0
#   日本: 0
#   日: 0
#   東洋: 0
# Total Frequency: 0
# ----------------------------------------
# File: 回风.txt
# Phrase Frequencies:
#   日本國: 0
#   日本: 0
#   日: 0
#   東洋: 0
# Total Frequency: 0
# ----------------------------------------
# File: 地下都会与海底森林.txt
# Phrase Frequencies:
#   日本國: 0
#   日本: 0
#   日: 0
#   東洋: 0
# Total Frequency: 0
# ----------------------------------------
# File: 岛国归婚记.txt
# Phrase Frequencies:
#   日本國: 0
#   日本: 0
#   日: 0
#   東洋: 0
# Total Frequency: 0
# ----------------------------------------
# File: 弟.txt
# Phrase Frequencies:
#   日本國: 0
#   日本: 0
#   日: 0
#   東洋: 0
# Total Frequency: 0
# ----------------------------------------
# File: 怪国探险记.txt
# Phrase Frequencies:
#   日本國: 0
#   日本: 0
#   日: 0
#   東洋: 0
# Total Frequency: 0
# ----------------------------------------
# File: 新殖民地仲尼島.txt
# Phrase Frequencies:
#   日本國: 0
#   日本: 0
#   日: 0
#   東洋: 0
# Total Frequency: 0
# ----------------------------------------
# File: 树穴书.txt
# Phrase Frequencies:
#   日本國: 0
#   日本: 0
#   日: 0
#   東洋: 0
# Total Frequency: 0
# ----------------------------------------
# File: 毒洲探险记.txt
# Phrase Frequencies:
#   日本國: 0
#   日本: 0
#   日: 0
#   東洋: 0
# Total Frequency: 0
# ----------------------------------------
# File: 海上逸史.txt
# Phrase Frequencies:
#   日本國: 0
#   日本: 0
#   日: 0
#   東洋: 0
# Total Frequency: 0
# ----------------------------------------
# File: 海底奇谈.txt
# Phrase Frequencies:
#   日本國: 0
#   日本: 0
#   日: 0
#   東洋: 0
# Total Frequency: 0
# ----------------------------------------
# File: 渔父冒险记 冠万.txt
# Phrase Frequencies:
#   日本國: 0
#   日本: 0
#   日: 0
#   東洋: 0
# Total Frequency: 0
# ----------------------------------------
# File: 渔父冒险记 孙明兴.txt
# Phrase Frequencies:
#   日本國: 0
#   日本: 0
#   日: 0
#   東洋: 0
# Total Frequency: 0
# ----------------------------------------
# File: 渔父冒险记 林远隆.txt
# Phrase Frequencies:
#   日本國: 0
#   日本: 0
#   日: 0
#   東洋: 0
# Total Frequency: 0
# ----------------------------------------
# File: 渔父冒险记 黄荣仙.txt
# Phrase Frequencies:
#   日本國: 0
#   日本: 0
#   日: 0
#   東洋: 0
# Total Frequency: 0
# ----------------------------------------
# File: 滕半仙伝.txt
# Phrase Frequencies:
#   日本國: 0
#   日本: 0
#   日: 0
#   東洋: 0
# Total Frequency: 0
# ----------------------------------------
# File: 片帆影.txt
# Phrase Frequencies:
#   日本國: 0
#   日本: 0
#   日: 0
#   東洋: 0
# Total Frequency: 0
# ----------------------------------------
# File: 狮子血.txt
# Phrase Frequencies:
#   日本國: 0
#   日本: 0
#   日: 0
#   東洋: 0
# Total Frequency: 0
# ----------------------------------------
# File: 狼吻余生记.txt
# Phrase Frequencies:
#   日本國: 0
#   日本: 0
#   日: 0
#   東洋: 0
# Total Frequency: 0
# ----------------------------------------
# File: 百斯笃殖民政策记.txt
# Phrase Frequencies:
#   日本國: 0
#   日本: 0
#   日: 0
#   東洋: 0
# Total Frequency: 0
# ----------------------------------------
# File: 盗盗.txt
# Phrase Frequencies:
#   日本國: 0
#   日本: 0
#   日: 0
#   東洋: 0
# Total Frequency: 0
# ----------------------------------------
# File: 破舟遇险记.txt
# Phrase Frequencies:
#   日本國: 0
#   日本: 0
#   日: 0
#   東洋: 0
# Total Frequency: 0
# ----------------------------------------
# File: 穴居.txt
# Phrase Frequencies:
#   日本國: 0
#   日本: 0
#   日: 0
#   東洋: 0
# Total Frequency: 0
# ----------------------------------------
# File: 空中岛.txt
# Phrase Frequencies:
#   日本國: 0
#   日本: 0
#   日: 0
#   東洋: 0
# Total Frequency: 0
# ----------------------------------------
# File: 纪实冒险小说洞庭湖.txt
# Phrase Frequencies:
#   日本國: 0
#   日本: 0
#   日: 0
#   東洋: 0
# Total Frequency: 0
# ----------------------------------------
# File: 航海奇遇.txt
# Phrase Frequencies:
#   日本國: 0
#   日本: 0
#   日: 0
#   東洋: 0
# Total Frequency: 0
# ----------------------------------------
# File: 航船盗.txt
# Phrase Frequencies:
#   日本國: 0
#   日本: 0
#   日: 0
#   東洋: 0
# Total Frequency: 0
# ----------------------------------------
# File: 英男孝女记.txt
# Phrase Frequencies:
#   日本國: 0
#   日本: 0
#   日: 0
#   東洋: 0
# Total Frequency: 0
# ----------------------------------------
# File: 荒岛孤踪.txt
# Phrase Frequencies:
#   日本國: 0
#   日本: 0
#   日: 0
#   東洋: 0
# Total Frequency: 0
# ----------------------------------------
# File: 荒岛漂泊记.txt
# Phrase Frequencies:
#   日本國: 0
#   日本: 0
#   日: 0
#   東洋: 0
# Total Frequency: 0
# ----------------------------------------
# File: 蛇虎斗.txt
# Phrase Frequencies:
#   日本國: 0
#   日本: 0
#   日: 0
#   東洋: 0
# Total Frequency: 0
# ----------------------------------------
# File: 记事小说虎口余生记.txt
# Phrase Frequencies:
#   日本國: 0
#   日本: 0
#   日: 0
#   東洋: 0
# Total Frequency: 0
# ----------------------------------------
# File: 陆治斯南极探险事.txt
# Phrase Frequencies:
#   日本國: 0
#   日本: 0
#   日: 0
#   東洋: 0
# Total Frequency: 0
# ----------------------------------------
# File: 青铜钱.txt
# Phrase Frequencies:
#   日本國: 0
#   日本: 0
#   日: 0
#   東洋: 0
# Total Frequency: 0
# ----------------------------------------
# File: 非洲探险记.txt
# Phrase Frequencies:
#   日本國: 0
#   日本: 0
#   日: 0
#   東洋: 0
# Total Frequency: 0
# ----------------------------------------
# File: 魔窟.txt
# Phrase Frequencies:
#   日本國: 0
#   日本: 0
#   日: 0
#   東洋: 0
# Total Frequency: 0
# ----------------------------------------
# File: 鱼丽水历险记.txt
# Phrase Frequencies:
#   日本國: 0
#   日本: 0
#   日: 0
#   東洋: 0
# Total Frequency: 0
# ----------------------------------------
# File: 鸭蛋岛探险记.txt
# Phrase Frequencies:
#   日本國: 0
#   日本: 0
#   日: 0
#   東洋: 0
# Total Frequency: 0
# ----------------------------------------
# Sum of Frequencies Across All Files:
#   日本國: 3
#   日本: 82
#   日: 3
#   東洋: 9

# %%
from collections import Counter

# Initialize a dictionary to store phrase frequencies for each file
phrase_freq_dict = {}

# Define the specific phrases we care about
phrases_we_care = {"日本", "日本國", "日", "東洋"}

# Define the tags we care about
tags_we_care = {'LOC', 'NORP', 'GPE'}

# Initialize a dictionary to store the sum of frequencies across all files
total_freq_across_files = {phrase: 0 for phrase in phrases_we_care}

# Counter to track the number of files containing at least one of the phrases
files_with_phrases = 0

# Iterate over each file in the results_dict
for file_name, file_data in results_dict.items():
    # Extract all_tags from the file data
    all_tags = file_data.get('all_tags', [])
    
    # Count the frequency of each specific phrase (only for tags in tags_we_care)
    phrase_counter = Counter(
        phrase for phrase, tag, _, _ in all_tags
        if tag in tags_we_care and phrase in phrases_we_care
    )
    
    # If the file contains at least one of the phrases, increment the counter
    if phrase_counter:
        files_with_phrases += 1
    
    # Store the phrase frequencies in the dictionary
    phrase_freq_dict[file_name] = {
        'phrase_freq': dict(phrase_counter),
        'total_freq': sum(phrase_counter.values())  # Sum of all phrase frequencies
    }
    
    # Update the total frequency across all files
    for phrase, freq in phrase_counter.items():
        total_freq_across_files[phrase] += freq

# Sort files by the total frequency of phrases (descending order)
sorted_files = sorted(phrase_freq_dict.items(), key=lambda x: x[1]['total_freq'], reverse=True)

# Print the results for each file
for file_name, data in sorted_files:
    print(f"File: {file_name}")
    print("Phrase Frequencies:")
    for phrase in phrases_we_care:
        freq = data['phrase_freq'].get(phrase, 0)  # Get frequency or 0 if phrase not found
        print(f"  {phrase}: {freq}")
    print(f"Total Frequency: {data['total_freq']}")
    print("-" * 40)  # Separator for readability

# Print the sum of frequencies across all files
print("Sum of Frequencies Across All Files:")
for phrase, total_freq in total_freq_across_files.items():
    print(f"  {phrase}: {total_freq}")

# Print the number of files containing at least one of the phrases
print(f"\nNumber of files containing at least one of the phrases: {files_with_phrases}")
# Out:
# File: 革命党.txt
# Phrase Frequencies:
#   日本國: 0
#   日本: 49
#   日: 0
#   東洋: 5
# Total Frequency: 54
# ----------------------------------------
# File: 月球殖民地小說.txt
# Phrase Frequencies:
#   日本國: 3
#   日本: 26
#   日: 1
#   東洋: 4
# Total Frequency: 34
# ----------------------------------------
# File: 冒险小说航海家儿.txt
# Phrase Frequencies:
#   日本國: 0
#   日本: 2
#   日: 0
#   東洋: 0
# Total Frequency: 2
# ----------------------------------------
# File: 小中华.txt
# Phrase Frequencies:
#   日本國: 0
#   日本: 2
#   日: 0
#   東洋: 0
# Total Frequency: 2
# ----------------------------------------
# File: 探险英雄传.txt
# Phrase Frequencies:
#   日本國: 0
#   日本: 0
#   日: 2
#   東洋: 0
# Total Frequency: 2
# ----------------------------------------
# File: 女丈夫.txt
# Phrase Frequencies:
#   日本國: 0
#   日本: 1
#   日: 0
#   東洋: 0
# Total Frequency: 1
# ----------------------------------------
# File: 磊落士官.txt
# Phrase Frequencies:
#   日本國: 0
#   日本: 1
#   日: 0
#   東洋: 0
# Total Frequency: 1
# ----------------------------------------
# File: 驮轮御风记.txt
# Phrase Frequencies:
#   日本國: 0
#   日本: 1
#   日: 0
#   東洋: 0
# Total Frequency: 1
# ----------------------------------------
# File: 不可思议.txt
# Phrase Frequencies:
#   日本國: 0
#   日本: 0
#   日: 0
#   東洋: 0
# Total Frequency: 0
# ----------------------------------------
# File: 中央亚非利加之蛮地探险.txt
# Phrase Frequencies:
#   日本國: 0
#   日本: 0
#   日: 0
#   東洋: 0
# Total Frequency: 0
# ----------------------------------------
# File: 冒险夜行.txt
# Phrase Frequencies:
#   日本國: 0
#   日本: 0
#   日: 0
#   東洋: 0
# Total Frequency: 0
# ----------------------------------------
# File: 冒险奇谈.txt
# Phrase Frequencies:
#   日本國: 0
#   日本: 0
#   日: 0
#   東洋: 0
# Total Frequency: 0
# ----------------------------------------
# File: 冒险小说孤店村.txt
# Phrase Frequencies:
#   日本國: 0
#   日本: 0
#   日: 0
#   東洋: 0
# Total Frequency: 0
# ----------------------------------------
# File: 冒险小说柏麦船长航海谈.txt
# Phrase Frequencies:
#   日本國: 0
#   日本: 0
#   日: 0
#   東洋: 0
# Total Frequency: 0
# ----------------------------------------
# File: 冒险小说火山岛.txt
# Phrase Frequencies:
#   日本國: 0
#   日本: 0
#   日: 0
#   東洋: 0
# Total Frequency: 0
# ----------------------------------------
# File: 冒险小说金沙窟.txt
# Phrase Frequencies:
#   日本國: 0
#   日本: 0
#   日: 0
#   東洋: 0
# Total Frequency: 0
# ----------------------------------------
# File: 冒险小说鬼域.txt
# Phrase Frequencies:
#   日本國: 0
#   日本: 0
#   日: 0
#   東洋: 0
# Total Frequency: 0
# ----------------------------------------
# File: 冒险成功之商界伟人.txt
# Phrase Frequencies:
#   日本國: 0
#   日本: 0
#   日: 0
#   東洋: 0
# Total Frequency: 0
# ----------------------------------------
# File: 冢中怪.txt
# Phrase Frequencies:
#   日本國: 0
#   日本: 0
#   日: 0
#   東洋: 0
# Total Frequency: 0
# ----------------------------------------
# File: 北冰洋归客谈.txt
# Phrase Frequencies:
#   日本國: 0
#   日本: 0
#   日: 0
#   東洋: 0
# Total Frequency: 0
# ----------------------------------------
# File: 南斐洲脱险记.txt
# Phrase Frequencies:
#   日本國: 0
#   日本: 0
#   日: 0
#   東洋: 0
# Total Frequency: 0
# ----------------------------------------
# File: 叶兰.txt
# Phrase Frequencies:
#   日本國: 0
#   日本: 0
#   日: 0
#   東洋: 0
# Total Frequency: 0
# ----------------------------------------
# File: 司宾洛.txt
# Phrase Frequencies:
#   日本國: 0
#   日本: 0
#   日: 0
#   東洋: 0
# Total Frequency: 0
# ----------------------------------------
# File: 回风.txt
# Phrase Frequencies:
#   日本國: 0
#   日本: 0
#   日: 0
#   東洋: 0
# Total Frequency: 0
# ----------------------------------------
# File: 地下都会与海底森林.txt
# Phrase Frequencies:
#   日本國: 0
#   日本: 0
#   日: 0
#   東洋: 0
# Total Frequency: 0
# ----------------------------------------
# File: 岛国归婚记.txt
# Phrase Frequencies:
#   日本國: 0
#   日本: 0
#   日: 0
#   東洋: 0
# Total Frequency: 0
# ----------------------------------------
# File: 弟.txt
# Phrase Frequencies:
#   日本國: 0
#   日本: 0
#   日: 0
#   東洋: 0
# Total Frequency: 0
# ----------------------------------------
# File: 怪国探险记.txt
# Phrase Frequencies:
#   日本國: 0
#   日本: 0
#   日: 0
#   東洋: 0
# Total Frequency: 0
# ----------------------------------------
# File: 新殖民地仲尼島.txt
# Phrase Frequencies:
#   日本國: 0
#   日本: 0
#   日: 0
#   東洋: 0
# Total Frequency: 0
# ----------------------------------------
# File: 树穴书.txt
# Phrase Frequencies:
#   日本國: 0
#   日本: 0
#   日: 0
#   東洋: 0
# Total Frequency: 0
# ----------------------------------------
# File: 毒洲探险记.txt
# Phrase Frequencies:
#   日本國: 0
#   日本: 0
#   日: 0
#   東洋: 0
# Total Frequency: 0
# ----------------------------------------
# File: 海上逸史.txt
# Phrase Frequencies:
#   日本國: 0
#   日本: 0
#   日: 0
#   東洋: 0
# Total Frequency: 0
# ----------------------------------------
# File: 海底奇谈.txt
# Phrase Frequencies:
#   日本國: 0
#   日本: 0
#   日: 0
#   東洋: 0
# Total Frequency: 0
# ----------------------------------------
# File: 渔父冒险记 冠万.txt
# Phrase Frequencies:
#   日本國: 0
#   日本: 0
#   日: 0
#   東洋: 0
# Total Frequency: 0
# ----------------------------------------
# File: 渔父冒险记 孙明兴.txt
# Phrase Frequencies:
#   日本國: 0
#   日本: 0
#   日: 0
#   東洋: 0
# Total Frequency: 0
# ----------------------------------------
# File: 渔父冒险记 林远隆.txt
# Phrase Frequencies:
#   日本國: 0
#   日本: 0
#   日: 0
#   東洋: 0
# Total Frequency: 0
# ----------------------------------------
# File: 渔父冒险记 黄荣仙.txt
# Phrase Frequencies:
#   日本國: 0
#   日本: 0
#   日: 0
#   東洋: 0
# Total Frequency: 0
# ----------------------------------------
# File: 滕半仙伝.txt
# Phrase Frequencies:
#   日本國: 0
#   日本: 0
#   日: 0
#   東洋: 0
# Total Frequency: 0
# ----------------------------------------
# File: 片帆影.txt
# Phrase Frequencies:
#   日本國: 0
#   日本: 0
#   日: 0
#   東洋: 0
# Total Frequency: 0
# ----------------------------------------
# File: 狮子血.txt
# Phrase Frequencies:
#   日本國: 0
#   日本: 0
#   日: 0
#   東洋: 0
# Total Frequency: 0
# ----------------------------------------
# File: 狼吻余生记.txt
# Phrase Frequencies:
#   日本國: 0
#   日本: 0
#   日: 0
#   東洋: 0
# Total Frequency: 0
# ----------------------------------------
# File: 百斯笃殖民政策记.txt
# Phrase Frequencies:
#   日本國: 0
#   日本: 0
#   日: 0
#   東洋: 0
# Total Frequency: 0
# ----------------------------------------
# File: 盗盗.txt
# Phrase Frequencies:
#   日本國: 0
#   日本: 0
#   日: 0
#   東洋: 0
# Total Frequency: 0
# ----------------------------------------
# File: 破舟遇险记.txt
# Phrase Frequencies:
#   日本國: 0
#   日本: 0
#   日: 0
#   東洋: 0
# Total Frequency: 0
# ----------------------------------------
# File: 穴居.txt
# Phrase Frequencies:
#   日本國: 0
#   日本: 0
#   日: 0
#   東洋: 0
# Total Frequency: 0
# ----------------------------------------
# File: 空中岛.txt
# Phrase Frequencies:
#   日本國: 0
#   日本: 0
#   日: 0
#   東洋: 0
# Total Frequency: 0
# ----------------------------------------
# File: 纪实冒险小说洞庭湖.txt
# Phrase Frequencies:
#   日本國: 0
#   日本: 0
#   日: 0
#   東洋: 0
# Total Frequency: 0
# ----------------------------------------
# File: 航海奇遇.txt
# Phrase Frequencies:
#   日本國: 0
#   日本: 0
#   日: 0
#   東洋: 0
# Total Frequency: 0
# ----------------------------------------
# File: 航船盗.txt
# Phrase Frequencies:
#   日本國: 0
#   日本: 0
#   日: 0
#   東洋: 0
# Total Frequency: 0
# ----------------------------------------
# File: 英男孝女记.txt
# Phrase Frequencies:
#   日本國: 0
#   日本: 0
#   日: 0
#   東洋: 0
# Total Frequency: 0
# ----------------------------------------
# File: 荒岛孤踪.txt
# Phrase Frequencies:
#   日本國: 0
#   日本: 0
#   日: 0
#   東洋: 0
# Total Frequency: 0
# ----------------------------------------
# File: 荒岛漂泊记.txt
# Phrase Frequencies:
#   日本國: 0
#   日本: 0
#   日: 0
#   東洋: 0
# Total Frequency: 0
# ----------------------------------------
# File: 蛇虎斗.txt
# Phrase Frequencies:
#   日本國: 0
#   日本: 0
#   日: 0
#   東洋: 0
# Total Frequency: 0
# ----------------------------------------
# File: 记事小说虎口余生记.txt
# Phrase Frequencies:
#   日本國: 0
#   日本: 0
#   日: 0
#   東洋: 0
# Total Frequency: 0
# ----------------------------------------
# File: 陆治斯南极探险事.txt
# Phrase Frequencies:
#   日本國: 0
#   日本: 0
#   日: 0
#   東洋: 0
# Total Frequency: 0
# ----------------------------------------
# File: 青铜钱.txt
# Phrase Frequencies:
#   日本國: 0
#   日本: 0
#   日: 0
#   東洋: 0
# Total Frequency: 0
# ----------------------------------------
# File: 非洲探险记.txt
# Phrase Frequencies:
#   日本國: 0
#   日本: 0
#   日: 0
#   東洋: 0
# Total Frequency: 0
# ----------------------------------------
# File: 魔窟.txt
# Phrase Frequencies:
#   日本國: 0
#   日本: 0
#   日: 0
#   東洋: 0
# Total Frequency: 0
# ----------------------------------------
# File: 鱼丽水历险记.txt
# Phrase Frequencies:
#   日本國: 0
#   日本: 0
#   日: 0
#   東洋: 0
# Total Frequency: 0
# ----------------------------------------
# File: 鸭蛋岛探险记.txt
# Phrase Frequencies:
#   日本國: 0
#   日本: 0
#   日: 0
#   東洋: 0
# Total Frequency: 0
# ----------------------------------------
# Sum of Frequencies Across All Files:
#   日本國: 3
#   日本: 82
#   日: 3
#   東洋: 9
#
# Number of files containing at least one of the phrases: 8

# %%
from collections import Counter

# Initialize a dictionary to store phrase frequencies for each file
phrase_freq_dict = {}

# Define the specific phrases we care about
phrases_we_care = {"非洲", "亞非利加", "非", "斐洲","阿非利加","菲州"}

# Define the tags we care about
tags_we_care = {'LOC', 'NORP', 'GPE'}

# Initialize a dictionary to store the sum of frequencies across all files
total_freq_across_files = {phrase: 0 for phrase in phrases_we_care}

# Counter to track the number of files containing at least one of the phrases
files_with_phrases = 0

# Iterate over each file in the results_dict
for file_name, file_data in results_dict.items():
    # Extract all_tags from the file data
    all_tags = file_data.get('all_tags', [])
    
    # Count the frequency of each specific phrase (only for tags in tags_we_care)
    phrase_counter = Counter(
        phrase for phrase, tag, _, _ in all_tags
        if tag in tags_we_care and phrase in phrases_we_care
    )
    
    # If the file contains at least one of the phrases, increment the counter
    if phrase_counter:
        files_with_phrases += 1
    
    # Store the phrase frequencies in the dictionary
    phrase_freq_dict[file_name] = {
        'phrase_freq': dict(phrase_counter),
        'total_freq': sum(phrase_counter.values())  # Sum of all phrase frequencies
    }
    
    # Update the total frequency across all files
    for phrase, freq in phrase_counter.items():
        total_freq_across_files[phrase] += freq

# Sort files by the total frequency of phrases (descending order)
sorted_files = sorted(phrase_freq_dict.items(), key=lambda x: x[1]['total_freq'], reverse=True)

# Print the results for each file
for file_name, data in sorted_files:
    print(f"File: {file_name}")
    print("Phrase Frequencies:")
    for phrase in phrases_we_care:
        freq = data['phrase_freq'].get(phrase, 0)  # Get frequency or 0 if phrase not found
        print(f"  {phrase}: {freq}")
    print(f"Total Frequency: {data['total_freq']}")
    print("-" * 40)  # Separator for readability

# Print the sum of frequencies across all files
print("Sum of Frequencies Across All Files:")
for phrase, total_freq in total_freq_across_files.items():
    print(f"  {phrase}: {total_freq}")

# Print the number of files containing at least one of the phrases
print(f"\nNumber of files containing at least one of the phrases: {files_with_phrases}")
# Out:
# File: 非洲探险记.txt
# Phrase Frequencies:
#   非: 1
#   阿非利加: 0
#   非洲: 24
#   斐洲: 0
#   亞非利加: 0
#   菲州: 0
# Total Frequency: 25
# ----------------------------------------
# File: 中央亚非利加之蛮地探险.txt
# Phrase Frequencies:
#   非: 0
#   阿非利加: 0
#   非洲: 4
#   斐洲: 0
#   亞非利加: 4
#   菲州: 0
# Total Frequency: 8
# ----------------------------------------
# File: 月球殖民地小說.txt
# Phrase Frequencies:
#   非: 0
#   阿非利加: 0
#   非洲: 7
#   斐洲: 0
#   亞非利加: 0
#   菲州: 0
# Total Frequency: 7
# ----------------------------------------
# File: 狮子血.txt
# Phrase Frequencies:
#   非: 0
#   阿非利加: 0
#   非洲: 4
#   斐洲: 0
#   亞非利加: 0
#   菲州: 0
# Total Frequency: 4
# ----------------------------------------
# File: 南斐洲脱险记.txt
# Phrase Frequencies:
#   非: 0
#   阿非利加: 0
#   非洲: 0
#   斐洲: 2
#   亞非利加: 0
#   菲州: 0
# Total Frequency: 2
# ----------------------------------------
# File: 海上逸史.txt
# Phrase Frequencies:
#   非: 0
#   阿非利加: 0
#   非洲: 0
#   斐洲: 0
#   亞非利加: 2
#   菲州: 0
# Total Frequency: 2
# ----------------------------------------
# File: 冒险小说柏麦船长航海谈.txt
# Phrase Frequencies:
#   非: 0
#   阿非利加: 0
#   非洲: 0
#   斐洲: 0
#   亞非利加: 1
#   菲州: 0
# Total Frequency: 1
# ----------------------------------------
# File: 冒险成功之商界伟人.txt
# Phrase Frequencies:
#   非: 1
#   阿非利加: 0
#   非洲: 0
#   斐洲: 0
#   亞非利加: 0
#   菲州: 0
# Total Frequency: 1
# ----------------------------------------
# File: 荒岛孤踪.txt
# Phrase Frequencies:
#   非: 0
#   阿非利加: 0
#   非洲: 0
#   斐洲: 0
#   亞非利加: 0
#   菲州: 1
# Total Frequency: 1
# ----------------------------------------
# File: 不可思议.txt
# Phrase Frequencies:
#   非: 0
#   阿非利加: 0
#   非洲: 0
#   斐洲: 0
#   亞非利加: 0
#   菲州: 0
# Total Frequency: 0
# ----------------------------------------
# File: 冒险夜行.txt
# Phrase Frequencies:
#   非: 0
#   阿非利加: 0
#   非洲: 0
#   斐洲: 0
#   亞非利加: 0
#   菲州: 0
# Total Frequency: 0
# ----------------------------------------
# File: 冒险奇谈.txt
# Phrase Frequencies:
#   非: 0
#   阿非利加: 0
#   非洲: 0
#   斐洲: 0
#   亞非利加: 0
#   菲州: 0
# Total Frequency: 0
# ----------------------------------------
# File: 冒险小说孤店村.txt
# Phrase Frequencies:
#   非: 0
#   阿非利加: 0
#   非洲: 0
#   斐洲: 0
#   亞非利加: 0
#   菲州: 0
# Total Frequency: 0
# ----------------------------------------
# File: 冒险小说火山岛.txt
# Phrase Frequencies:
#   非: 0
#   阿非利加: 0
#   非洲: 0
#   斐洲: 0
#   亞非利加: 0
#   菲州: 0
# Total Frequency: 0
# ----------------------------------------
# File: 冒险小说航海家儿.txt
# Phrase Frequencies:
#   非: 0
#   阿非利加: 0
#   非洲: 0
#   斐洲: 0
#   亞非利加: 0
#   菲州: 0
# Total Frequency: 0
# ----------------------------------------
# File: 冒险小说金沙窟.txt
# Phrase Frequencies:
#   非: 0
#   阿非利加: 0
#   非洲: 0
#   斐洲: 0
#   亞非利加: 0
#   菲州: 0
# Total Frequency: 0
# ----------------------------------------
# File: 冒险小说鬼域.txt
# Phrase Frequencies:
#   非: 0
#   阿非利加: 0
#   非洲: 0
#   斐洲: 0
#   亞非利加: 0
#   菲州: 0
# Total Frequency: 0
# ----------------------------------------
# File: 冢中怪.txt
# Phrase Frequencies:
#   非: 0
#   阿非利加: 0
#   非洲: 0
#   斐洲: 0
#   亞非利加: 0
#   菲州: 0
# Total Frequency: 0
# ----------------------------------------
# File: 北冰洋归客谈.txt
# Phrase Frequencies:
#   非: 0
#   阿非利加: 0
#   非洲: 0
#   斐洲: 0
#   亞非利加: 0
#   菲州: 0
# Total Frequency: 0
# ----------------------------------------
# File: 叶兰.txt
# Phrase Frequencies:
#   非: 0
#   阿非利加: 0
#   非洲: 0
#   斐洲: 0
#   亞非利加: 0
#   菲州: 0
# Total Frequency: 0
# ----------------------------------------
# File: 司宾洛.txt
# Phrase Frequencies:
#   非: 0
#   阿非利加: 0
#   非洲: 0
#   斐洲: 0
#   亞非利加: 0
#   菲州: 0
# Total Frequency: 0
# ----------------------------------------
# File: 回风.txt
# Phrase Frequencies:
#   非: 0
#   阿非利加: 0
#   非洲: 0
#   斐洲: 0
#   亞非利加: 0
#   菲州: 0
# Total Frequency: 0
# ----------------------------------------
# File: 地下都会与海底森林.txt
# Phrase Frequencies:
#   非: 0
#   阿非利加: 0
#   非洲: 0
#   斐洲: 0
#   亞非利加: 0
#   菲州: 0
# Total Frequency: 0
# ----------------------------------------
# File: 女丈夫.txt
# Phrase Frequencies:
#   非: 0
#   阿非利加: 0
#   非洲: 0
#   斐洲: 0
#   亞非利加: 0
#   菲州: 0
# Total Frequency: 0
# ----------------------------------------
# File: 小中华.txt
# Phrase Frequencies:
#   非: 0
#   阿非利加: 0
#   非洲: 0
#   斐洲: 0
#   亞非利加: 0
#   菲州: 0
# Total Frequency: 0
# ----------------------------------------
# File: 岛国归婚记.txt
# Phrase Frequencies:
#   非: 0
#   阿非利加: 0
#   非洲: 0
#   斐洲: 0
#   亞非利加: 0
#   菲州: 0
# Total Frequency: 0
# ----------------------------------------
# File: 弟.txt
# Phrase Frequencies:
#   非: 0
#   阿非利加: 0
#   非洲: 0
#   斐洲: 0
#   亞非利加: 0
#   菲州: 0
# Total Frequency: 0
# ----------------------------------------
# File: 怪国探险记.txt
# Phrase Frequencies:
#   非: 0
#   阿非利加: 0
#   非洲: 0
#   斐洲: 0
#   亞非利加: 0
#   菲州: 0
# Total Frequency: 0
# ----------------------------------------
# File: 探险英雄传.txt
# Phrase Frequencies:
#   非: 0
#   阿非利加: 0
#   非洲: 0
#   斐洲: 0
#   亞非利加: 0
#   菲州: 0
# Total Frequency: 0
# ----------------------------------------
# File: 新殖民地仲尼島.txt
# Phrase Frequencies:
#   非: 0
#   阿非利加: 0
#   非洲: 0
#   斐洲: 0
#   亞非利加: 0
#   菲州: 0
# Total Frequency: 0
# ----------------------------------------
# File: 树穴书.txt
# Phrase Frequencies:
#   非: 0
#   阿非利加: 0
#   非洲: 0
#   斐洲: 0
#   亞非利加: 0
#   菲州: 0
# Total Frequency: 0
# ----------------------------------------
# File: 毒洲探险记.txt
# Phrase Frequencies:
#   非: 0
#   阿非利加: 0
#   非洲: 0
#   斐洲: 0
#   亞非利加: 0
#   菲州: 0
# Total Frequency: 0
# ----------------------------------------
# File: 海底奇谈.txt
# Phrase Frequencies:
#   非: 0
#   阿非利加: 0
#   非洲: 0
#   斐洲: 0
#   亞非利加: 0
#   菲州: 0
# Total Frequency: 0
# ----------------------------------------
# File: 渔父冒险记 冠万.txt
# Phrase Frequencies:
#   非: 0
#   阿非利加: 0
#   非洲: 0
#   斐洲: 0
#   亞非利加: 0
#   菲州: 0
# Total Frequency: 0
# ----------------------------------------
# File: 渔父冒险记 孙明兴.txt
# Phrase Frequencies:
#   非: 0
#   阿非利加: 0
#   非洲: 0
#   斐洲: 0
#   亞非利加: 0
#   菲州: 0
# Total Frequency: 0
# ----------------------------------------
# File: 渔父冒险记 林远隆.txt
# Phrase Frequencies:
#   非: 0
#   阿非利加: 0
#   非洲: 0
#   斐洲: 0
#   亞非利加: 0
#   菲州: 0
# Total Frequency: 0
# ----------------------------------------
# File: 渔父冒险记 黄荣仙.txt
# Phrase Frequencies:
#   非: 0
#   阿非利加: 0
#   非洲: 0
#   斐洲: 0
#   亞非利加: 0
#   菲州: 0
# Total Frequency: 0
# ----------------------------------------
# File: 滕半仙伝.txt
# Phrase Frequencies:
#   非: 0
#   阿非利加: 0
#   非洲: 0
#   斐洲: 0
#   亞非利加: 0
#   菲州: 0
# Total Frequency: 0
# ----------------------------------------
# File: 片帆影.txt
# Phrase Frequencies:
#   非: 0
#   阿非利加: 0
#   非洲: 0
#   斐洲: 0
#   亞非利加: 0
#   菲州: 0
# Total Frequency: 0
# ----------------------------------------
# File: 狼吻余生记.txt
# Phrase Frequencies:
#   非: 0
#   阿非利加: 0
#   非洲: 0
#   斐洲: 0
#   亞非利加: 0
#   菲州: 0
# Total Frequency: 0
# ----------------------------------------
# File: 百斯笃殖民政策记.txt
# Phrase Frequencies:
#   非: 0
#   阿非利加: 0
#   非洲: 0
#   斐洲: 0
#   亞非利加: 0
#   菲州: 0
# Total Frequency: 0
# ----------------------------------------
# File: 盗盗.txt
# Phrase Frequencies:
#   非: 0
#   阿非利加: 0
#   非洲: 0
#   斐洲: 0
#   亞非利加: 0
#   菲州: 0
# Total Frequency: 0
# ----------------------------------------
# File: 破舟遇险记.txt
# Phrase Frequencies:
#   非: 0
#   阿非利加: 0
#   非洲: 0
#   斐洲: 0
#   亞非利加: 0
#   菲州: 0
# Total Frequency: 0
# ----------------------------------------
# File: 磊落士官.txt
# Phrase Frequencies:
#   非: 0
#   阿非利加: 0
#   非洲: 0
#   斐洲: 0
#   亞非利加: 0
#   菲州: 0
# Total Frequency: 0
# ----------------------------------------
# File: 穴居.txt
# Phrase Frequencies:
#   非: 0
#   阿非利加: 0
#   非洲: 0
#   斐洲: 0
#   亞非利加: 0
#   菲州: 0
# Total Frequency: 0
# ----------------------------------------
# File: 空中岛.txt
# Phrase Frequencies:
#   非: 0
#   阿非利加: 0
#   非洲: 0
#   斐洲: 0
#   亞非利加: 0
#   菲州: 0
# Total Frequency: 0
# ----------------------------------------
# File: 纪实冒险小说洞庭湖.txt
# Phrase Frequencies:
#   非: 0
#   阿非利加: 0
#   非洲: 0
#   斐洲: 0
#   亞非利加: 0
#   菲州: 0
# Total Frequency: 0
# ----------------------------------------
# File: 航海奇遇.txt
# Phrase Frequencies:
#   非: 0
#   阿非利加: 0
#   非洲: 0
#   斐洲: 0
#   亞非利加: 0
#   菲州: 0
# Total Frequency: 0
# ----------------------------------------
# File: 航船盗.txt
# Phrase Frequencies:
#   非: 0
#   阿非利加: 0
#   非洲: 0
#   斐洲: 0
#   亞非利加: 0
#   菲州: 0
# Total Frequency: 0
# ----------------------------------------
# File: 英男孝女记.txt
# Phrase Frequencies:
#   非: 0
#   阿非利加: 0
#   非洲: 0
#   斐洲: 0
#   亞非利加: 0
#   菲州: 0
# Total Frequency: 0
# ----------------------------------------
# File: 荒岛漂泊记.txt
# Phrase Frequencies:
#   非: 0
#   阿非利加: 0
#   非洲: 0
#   斐洲: 0
#   亞非利加: 0
#   菲州: 0
# Total Frequency: 0
# ----------------------------------------
# File: 蛇虎斗.txt
# Phrase Frequencies:
#   非: 0
#   阿非利加: 0
#   非洲: 0
#   斐洲: 0
#   亞非利加: 0
#   菲州: 0
# Total Frequency: 0
# ----------------------------------------
# File: 记事小说虎口余生记.txt
# Phrase Frequencies:
#   非: 0
#   阿非利加: 0
#   非洲: 0
#   斐洲: 0
#   亞非利加: 0
#   菲州: 0
# Total Frequency: 0
# ----------------------------------------
# File: 陆治斯南极探险事.txt
# Phrase Frequencies:
#   非: 0
#   阿非利加: 0
#   非洲: 0
#   斐洲: 0
#   亞非利加: 0
#   菲州: 0
# Total Frequency: 0
# ----------------------------------------
# File: 青铜钱.txt
# Phrase Frequencies:
#   非: 0
#   阿非利加: 0
#   非洲: 0
#   斐洲: 0
#   亞非利加: 0
#   菲州: 0
# Total Frequency: 0
# ----------------------------------------
# File: 革命党.txt
# Phrase Frequencies:
#   非: 0
#   阿非利加: 0
#   非洲: 0
#   斐洲: 0
#   亞非利加: 0
#   菲州: 0
# Total Frequency: 0
# ----------------------------------------
# File: 驮轮御风记.txt
# Phrase Frequencies:
#   非: 0
#   阿非利加: 0
#   非洲: 0
#   斐洲: 0
#   亞非利加: 0
#   菲州: 0
# Total Frequency: 0
# ----------------------------------------
# File: 魔窟.txt
# Phrase Frequencies:
#   非: 0
#   阿非利加: 0
#   非洲: 0
#   斐洲: 0
#   亞非利加: 0
#   菲州: 0
# Total Frequency: 0
# ----------------------------------------
# File: 鱼丽水历险记.txt
# Phrase Frequencies:
#   非: 0
#   阿非利加: 0
#   非洲: 0
#   斐洲: 0
#   亞非利加: 0
#   菲州: 0
# Total Frequency: 0
# ----------------------------------------
# File: 鸭蛋岛探险记.txt
# Phrase Frequencies:
#   非: 0
#   阿非利加: 0
#   非洲: 0
#   斐洲: 0
#   亞非利加: 0
#   菲州: 0
# Total Frequency: 0
# ----------------------------------------
# Sum of Frequencies Across All Files:
#   非: 2
#   阿非利加: 0
#   非洲: 39
#   斐洲: 2
#   亞非利加: 7
#   菲州: 1
#
# Number of files containing at least one of the phrases: 9

# %%
from collections import Counter

# Initialize a dictionary to store phrase frequencies for each file
phrase_freq_dict = {}

# Define the specific phrases we care about
phrases_we_care = {"亞洲", "亞細亞", "亞西亞洲", "亞西亞","亞西亞大陸","亞細亞洲","亞東"}

# Define the tags we care about
tags_we_care = {'LOC', 'NORP', 'GPE'}

# Initialize a dictionary to store the sum of frequencies across all files
total_freq_across_files = {phrase: 0 for phrase in phrases_we_care}

# Counter to track the number of files containing at least one of the phrases
files_with_phrases = 0

# Iterate over each file in the results_dict
for file_name, file_data in results_dict.items():
    # Extract all_tags from the file data
    all_tags = file_data.get('all_tags', [])
    
    # Count the frequency of each specific phrase (only for tags in tags_we_care)
    phrase_counter = Counter(
        phrase for phrase, tag, _, _ in all_tags
        if tag in tags_we_care and phrase in phrases_we_care
    )
    
    # If the file contains at least one of the phrases, increment the counter
    if phrase_counter:
        files_with_phrases += 1
    
    # Store the phrase frequencies in the dictionary
    phrase_freq_dict[file_name] = {
        'phrase_freq': dict(phrase_counter),
        'total_freq': sum(phrase_counter.values())  # Sum of all phrase frequencies
    }
    
    # Update the total frequency across all files
    for phrase, freq in phrase_counter.items():
        total_freq_across_files[phrase] += freq

# Sort files by the total frequency of phrases (descending order)
sorted_files = sorted(phrase_freq_dict.items(), key=lambda x: x[1]['total_freq'], reverse=True)

# Print the results for each file
for file_name, data in sorted_files:
    print(f"File: {file_name}")
    print("Phrase Frequencies:")
    for phrase in phrases_we_care:
        freq = data['phrase_freq'].get(phrase, 0)  # Get frequency or 0 if phrase not found
        print(f"  {phrase}: {freq}")
    print(f"Total Frequency: {data['total_freq']}")
    print("-" * 40)  # Separator for readability

# Print the sum of frequencies across all files
print("Sum of Frequencies Across All Files:")
for phrase, total_freq in total_freq_across_files.items():
    print(f"  {phrase}: {total_freq}")

# Print the number of files containing at least one of the phrases
print(f"\nNumber of files containing at least one of the phrases: {files_with_phrases}")
# Out:
# File: 月球殖民地小說.txt
# Phrase Frequencies:
#   亞西亞大陸: 0
#   亞細亞洲: 0
#   亞西亞: 0
#   亞西亞洲: 0
#   亞細亞: 0
#   亞東: 3
#   亞洲: 6
# Total Frequency: 9
# ----------------------------------------
# File: 鱼丽水历险记.txt
# Phrase Frequencies:
#   亞西亞大陸: 0
#   亞細亞洲: 1
#   亞西亞: 0
#   亞西亞洲: 0
#   亞細亞: 2
#   亞東: 0
#   亞洲: 3
# Total Frequency: 6
# ----------------------------------------
# File: 毒洲探险记.txt
# Phrase Frequencies:
#   亞西亞大陸: 0
#   亞細亞洲: 0
#   亞西亞: 0
#   亞西亞洲: 0
#   亞細亞: 0
#   亞東: 0
#   亞洲: 5
# Total Frequency: 5
# ----------------------------------------
# File: 女丈夫.txt
# Phrase Frequencies:
#   亞西亞大陸: 1
#   亞細亞洲: 0
#   亞西亞: 1
#   亞西亞洲: 1
#   亞細亞: 0
#   亞東: 0
#   亞洲: 0
# Total Frequency: 3
# ----------------------------------------
# File: 冒险成功之商界伟人.txt
# Phrase Frequencies:
#   亞西亞大陸: 0
#   亞細亞洲: 0
#   亞西亞: 0
#   亞西亞洲: 0
#   亞細亞: 0
#   亞東: 0
#   亞洲: 2
# Total Frequency: 2
# ----------------------------------------
# File: 怪国探险记.txt
# Phrase Frequencies:
#   亞西亞大陸: 0
#   亞細亞洲: 0
#   亞西亞: 0
#   亞西亞洲: 0
#   亞細亞: 0
#   亞東: 1
#   亞洲: 0
# Total Frequency: 1
# ----------------------------------------
# File: 新殖民地仲尼島.txt
# Phrase Frequencies:
#   亞西亞大陸: 0
#   亞細亞洲: 0
#   亞西亞: 0
#   亞西亞洲: 0
#   亞細亞: 0
#   亞東: 0
#   亞洲: 1
# Total Frequency: 1
# ----------------------------------------
# File: 狮子血.txt
# Phrase Frequencies:
#   亞西亞大陸: 0
#   亞細亞洲: 0
#   亞西亞: 0
#   亞西亞洲: 0
#   亞細亞: 0
#   亞東: 0
#   亞洲: 1
# Total Frequency: 1
# ----------------------------------------
# File: 魔窟.txt
# Phrase Frequencies:
#   亞西亞大陸: 0
#   亞細亞洲: 0
#   亞西亞: 0
#   亞西亞洲: 0
#   亞細亞: 0
#   亞東: 1
#   亞洲: 0
# Total Frequency: 1
# ----------------------------------------
# File: 不可思议.txt
# Phrase Frequencies:
#   亞西亞大陸: 0
#   亞細亞洲: 0
#   亞西亞: 0
#   亞西亞洲: 0
#   亞細亞: 0
#   亞東: 0
#   亞洲: 0
# Total Frequency: 0
# ----------------------------------------
# File: 中央亚非利加之蛮地探险.txt
# Phrase Frequencies:
#   亞西亞大陸: 0
#   亞細亞洲: 0
#   亞西亞: 0
#   亞西亞洲: 0
#   亞細亞: 0
#   亞東: 0
#   亞洲: 0
# Total Frequency: 0
# ----------------------------------------
# File: 冒险夜行.txt
# Phrase Frequencies:
#   亞西亞大陸: 0
#   亞細亞洲: 0
#   亞西亞: 0
#   亞西亞洲: 0
#   亞細亞: 0
#   亞東: 0
#   亞洲: 0
# Total Frequency: 0
# ----------------------------------------
# File: 冒险奇谈.txt
# Phrase Frequencies:
#   亞西亞大陸: 0
#   亞細亞洲: 0
#   亞西亞: 0
#   亞西亞洲: 0
#   亞細亞: 0
#   亞東: 0
#   亞洲: 0
# Total Frequency: 0
# ----------------------------------------
# File: 冒险小说孤店村.txt
# Phrase Frequencies:
#   亞西亞大陸: 0
#   亞細亞洲: 0
#   亞西亞: 0
#   亞西亞洲: 0
#   亞細亞: 0
#   亞東: 0
#   亞洲: 0
# Total Frequency: 0
# ----------------------------------------
# File: 冒险小说柏麦船长航海谈.txt
# Phrase Frequencies:
#   亞西亞大陸: 0
#   亞細亞洲: 0
#   亞西亞: 0
#   亞西亞洲: 0
#   亞細亞: 0
#   亞東: 0
#   亞洲: 0
# Total Frequency: 0
# ----------------------------------------
# File: 冒险小说火山岛.txt
# Phrase Frequencies:
#   亞西亞大陸: 0
#   亞細亞洲: 0
#   亞西亞: 0
#   亞西亞洲: 0
#   亞細亞: 0
#   亞東: 0
#   亞洲: 0
# Total Frequency: 0
# ----------------------------------------
# File: 冒险小说航海家儿.txt
# Phrase Frequencies:
#   亞西亞大陸: 0
#   亞細亞洲: 0
#   亞西亞: 0
#   亞西亞洲: 0
#   亞細亞: 0
#   亞東: 0
#   亞洲: 0
# Total Frequency: 0
# ----------------------------------------
# File: 冒险小说金沙窟.txt
# Phrase Frequencies:
#   亞西亞大陸: 0
#   亞細亞洲: 0
#   亞西亞: 0
#   亞西亞洲: 0
#   亞細亞: 0
#   亞東: 0
#   亞洲: 0
# Total Frequency: 0
# ----------------------------------------
# File: 冒险小说鬼域.txt
# Phrase Frequencies:
#   亞西亞大陸: 0
#   亞細亞洲: 0
#   亞西亞: 0
#   亞西亞洲: 0
#   亞細亞: 0
#   亞東: 0
#   亞洲: 0
# Total Frequency: 0
# ----------------------------------------
# File: 冢中怪.txt
# Phrase Frequencies:
#   亞西亞大陸: 0
#   亞細亞洲: 0
#   亞西亞: 0
#   亞西亞洲: 0
#   亞細亞: 0
#   亞東: 0
#   亞洲: 0
# Total Frequency: 0
# ----------------------------------------
# File: 北冰洋归客谈.txt
# Phrase Frequencies:
#   亞西亞大陸: 0
#   亞細亞洲: 0
#   亞西亞: 0
#   亞西亞洲: 0
#   亞細亞: 0
#   亞東: 0
#   亞洲: 0
# Total Frequency: 0
# ----------------------------------------
# File: 南斐洲脱险记.txt
# Phrase Frequencies:
#   亞西亞大陸: 0
#   亞細亞洲: 0
#   亞西亞: 0
#   亞西亞洲: 0
#   亞細亞: 0
#   亞東: 0
#   亞洲: 0
# Total Frequency: 0
# ----------------------------------------
# File: 叶兰.txt
# Phrase Frequencies:
#   亞西亞大陸: 0
#   亞細亞洲: 0
#   亞西亞: 0
#   亞西亞洲: 0
#   亞細亞: 0
#   亞東: 0
#   亞洲: 0
# Total Frequency: 0
# ----------------------------------------
# File: 司宾洛.txt
# Phrase Frequencies:
#   亞西亞大陸: 0
#   亞細亞洲: 0
#   亞西亞: 0
#   亞西亞洲: 0
#   亞細亞: 0
#   亞東: 0
#   亞洲: 0
# Total Frequency: 0
# ----------------------------------------
# File: 回风.txt
# Phrase Frequencies:
#   亞西亞大陸: 0
#   亞細亞洲: 0
#   亞西亞: 0
#   亞西亞洲: 0
#   亞細亞: 0
#   亞東: 0
#   亞洲: 0
# Total Frequency: 0
# ----------------------------------------
# File: 地下都会与海底森林.txt
# Phrase Frequencies:
#   亞西亞大陸: 0
#   亞細亞洲: 0
#   亞西亞: 0
#   亞西亞洲: 0
#   亞細亞: 0
#   亞東: 0
#   亞洲: 0
# Total Frequency: 0
# ----------------------------------------
# File: 小中华.txt
# Phrase Frequencies:
#   亞西亞大陸: 0
#   亞細亞洲: 0
#   亞西亞: 0
#   亞西亞洲: 0
#   亞細亞: 0
#   亞東: 0
#   亞洲: 0
# Total Frequency: 0
# ----------------------------------------
# File: 岛国归婚记.txt
# Phrase Frequencies:
#   亞西亞大陸: 0
#   亞細亞洲: 0
#   亞西亞: 0
#   亞西亞洲: 0
#   亞細亞: 0
#   亞東: 0
#   亞洲: 0
# Total Frequency: 0
# ----------------------------------------
# File: 弟.txt
# Phrase Frequencies:
#   亞西亞大陸: 0
#   亞細亞洲: 0
#   亞西亞: 0
#   亞西亞洲: 0
#   亞細亞: 0
#   亞東: 0
#   亞洲: 0
# Total Frequency: 0
# ----------------------------------------
# File: 探险英雄传.txt
# Phrase Frequencies:
#   亞西亞大陸: 0
#   亞細亞洲: 0
#   亞西亞: 0
#   亞西亞洲: 0
#   亞細亞: 0
#   亞東: 0
#   亞洲: 0
# Total Frequency: 0
# ----------------------------------------
# File: 树穴书.txt
# Phrase Frequencies:
#   亞西亞大陸: 0
#   亞細亞洲: 0
#   亞西亞: 0
#   亞西亞洲: 0
#   亞細亞: 0
#   亞東: 0
#   亞洲: 0
# Total Frequency: 0
# ----------------------------------------
# File: 海上逸史.txt
# Phrase Frequencies:
#   亞西亞大陸: 0
#   亞細亞洲: 0
#   亞西亞: 0
#   亞西亞洲: 0
#   亞細亞: 0
#   亞東: 0
#   亞洲: 0
# Total Frequency: 0
# ----------------------------------------
# File: 海底奇谈.txt
# Phrase Frequencies:
#   亞西亞大陸: 0
#   亞細亞洲: 0
#   亞西亞: 0
#   亞西亞洲: 0
#   亞細亞: 0
#   亞東: 0
#   亞洲: 0
# Total Frequency: 0
# ----------------------------------------
# File: 渔父冒险记 冠万.txt
# Phrase Frequencies:
#   亞西亞大陸: 0
#   亞細亞洲: 0
#   亞西亞: 0
#   亞西亞洲: 0
#   亞細亞: 0
#   亞東: 0
#   亞洲: 0
# Total Frequency: 0
# ----------------------------------------
# File: 渔父冒险记 孙明兴.txt
# Phrase Frequencies:
#   亞西亞大陸: 0
#   亞細亞洲: 0
#   亞西亞: 0
#   亞西亞洲: 0
#   亞細亞: 0
#   亞東: 0
#   亞洲: 0
# Total Frequency: 0
# ----------------------------------------
# File: 渔父冒险记 林远隆.txt
# Phrase Frequencies:
#   亞西亞大陸: 0
#   亞細亞洲: 0
#   亞西亞: 0
#   亞西亞洲: 0
#   亞細亞: 0
#   亞東: 0
#   亞洲: 0
# Total Frequency: 0
# ----------------------------------------
# File: 渔父冒险记 黄荣仙.txt
# Phrase Frequencies:
#   亞西亞大陸: 0
#   亞細亞洲: 0
#   亞西亞: 0
#   亞西亞洲: 0
#   亞細亞: 0
#   亞東: 0
#   亞洲: 0
# Total Frequency: 0
# ----------------------------------------
# File: 滕半仙伝.txt
# Phrase Frequencies:
#   亞西亞大陸: 0
#   亞細亞洲: 0
#   亞西亞: 0
#   亞西亞洲: 0
#   亞細亞: 0
#   亞東: 0
#   亞洲: 0
# Total Frequency: 0
# ----------------------------------------
# File: 片帆影.txt
# Phrase Frequencies:
#   亞西亞大陸: 0
#   亞細亞洲: 0
#   亞西亞: 0
#   亞西亞洲: 0
#   亞細亞: 0
#   亞東: 0
#   亞洲: 0
# Total Frequency: 0
# ----------------------------------------
# File: 狼吻余生记.txt
# Phrase Frequencies:
#   亞西亞大陸: 0
#   亞細亞洲: 0
#   亞西亞: 0
#   亞西亞洲: 0
#   亞細亞: 0
#   亞東: 0
#   亞洲: 0
# Total Frequency: 0
# ----------------------------------------
# File: 百斯笃殖民政策记.txt
# Phrase Frequencies:
#   亞西亞大陸: 0
#   亞細亞洲: 0
#   亞西亞: 0
#   亞西亞洲: 0
#   亞細亞: 0
#   亞東: 0
#   亞洲: 0
# Total Frequency: 0
# ----------------------------------------
# File: 盗盗.txt
# Phrase Frequencies:
#   亞西亞大陸: 0
#   亞細亞洲: 0
#   亞西亞: 0
#   亞西亞洲: 0
#   亞細亞: 0
#   亞東: 0
#   亞洲: 0
# Total Frequency: 0
# ----------------------------------------
# File: 破舟遇险记.txt
# Phrase Frequencies:
#   亞西亞大陸: 0
#   亞細亞洲: 0
#   亞西亞: 0
#   亞西亞洲: 0
#   亞細亞: 0
#   亞東: 0
#   亞洲: 0
# Total Frequency: 0
# ----------------------------------------
# File: 磊落士官.txt
# Phrase Frequencies:
#   亞西亞大陸: 0
#   亞細亞洲: 0
#   亞西亞: 0
#   亞西亞洲: 0
#   亞細亞: 0
#   亞東: 0
#   亞洲: 0
# Total Frequency: 0
# ----------------------------------------
# File: 穴居.txt
# Phrase Frequencies:
#   亞西亞大陸: 0
#   亞細亞洲: 0
#   亞西亞: 0
#   亞西亞洲: 0
#   亞細亞: 0
#   亞東: 0
#   亞洲: 0
# Total Frequency: 0
# ----------------------------------------
# File: 空中岛.txt
# Phrase Frequencies:
#   亞西亞大陸: 0
#   亞細亞洲: 0
#   亞西亞: 0
#   亞西亞洲: 0
#   亞細亞: 0
#   亞東: 0
#   亞洲: 0
# Total Frequency: 0
# ----------------------------------------
# File: 纪实冒险小说洞庭湖.txt
# Phrase Frequencies:
#   亞西亞大陸: 0
#   亞細亞洲: 0
#   亞西亞: 0
#   亞西亞洲: 0
#   亞細亞: 0
#   亞東: 0
#   亞洲: 0
# Total Frequency: 0
# ----------------------------------------
# File: 航海奇遇.txt
# Phrase Frequencies:
#   亞西亞大陸: 0
#   亞細亞洲: 0
#   亞西亞: 0
#   亞西亞洲: 0
#   亞細亞: 0
#   亞東: 0
#   亞洲: 0
# Total Frequency: 0
# ----------------------------------------
# File: 航船盗.txt
# Phrase Frequencies:
#   亞西亞大陸: 0
#   亞細亞洲: 0
#   亞西亞: 0
#   亞西亞洲: 0
#   亞細亞: 0
#   亞東: 0
#   亞洲: 0
# Total Frequency: 0
# ----------------------------------------
# File: 英男孝女记.txt
# Phrase Frequencies:
#   亞西亞大陸: 0
#   亞細亞洲: 0
#   亞西亞: 0
#   亞西亞洲: 0
#   亞細亞: 0
#   亞東: 0
#   亞洲: 0
# Total Frequency: 0
# ----------------------------------------
# File: 荒岛孤踪.txt
# Phrase Frequencies:
#   亞西亞大陸: 0
#   亞細亞洲: 0
#   亞西亞: 0
#   亞西亞洲: 0
#   亞細亞: 0
#   亞東: 0
#   亞洲: 0
# Total Frequency: 0
# ----------------------------------------
# File: 荒岛漂泊记.txt
# Phrase Frequencies:
#   亞西亞大陸: 0
#   亞細亞洲: 0
#   亞西亞: 0
#   亞西亞洲: 0
#   亞細亞: 0
#   亞東: 0
#   亞洲: 0
# Total Frequency: 0
# ----------------------------------------
# File: 蛇虎斗.txt
# Phrase Frequencies:
#   亞西亞大陸: 0
#   亞細亞洲: 0
#   亞西亞: 0
#   亞西亞洲: 0
#   亞細亞: 0
#   亞東: 0
#   亞洲: 0
# Total Frequency: 0
# ----------------------------------------
# File: 记事小说虎口余生记.txt
# Phrase Frequencies:
#   亞西亞大陸: 0
#   亞細亞洲: 0
#   亞西亞: 0
#   亞西亞洲: 0
#   亞細亞: 0
#   亞東: 0
#   亞洲: 0
# Total Frequency: 0
# ----------------------------------------
# File: 陆治斯南极探险事.txt
# Phrase Frequencies:
#   亞西亞大陸: 0
#   亞細亞洲: 0
#   亞西亞: 0
#   亞西亞洲: 0
#   亞細亞: 0
#   亞東: 0
#   亞洲: 0
# Total Frequency: 0
# ----------------------------------------
# File: 青铜钱.txt
# Phrase Frequencies:
#   亞西亞大陸: 0
#   亞細亞洲: 0
#   亞西亞: 0
#   亞西亞洲: 0
#   亞細亞: 0
#   亞東: 0
#   亞洲: 0
# Total Frequency: 0
# ----------------------------------------
# File: 非洲探险记.txt
# Phrase Frequencies:
#   亞西亞大陸: 0
#   亞細亞洲: 0
#   亞西亞: 0
#   亞西亞洲: 0
#   亞細亞: 0
#   亞東: 0
#   亞洲: 0
# Total Frequency: 0
# ----------------------------------------
# File: 革命党.txt
# Phrase Frequencies:
#   亞西亞大陸: 0
#   亞細亞洲: 0
#   亞西亞: 0
#   亞西亞洲: 0
#   亞細亞: 0
#   亞東: 0
#   亞洲: 0
# Total Frequency: 0
# ----------------------------------------
# File: 驮轮御风记.txt
# Phrase Frequencies:
#   亞西亞大陸: 0
#   亞細亞洲: 0
#   亞西亞: 0
#   亞西亞洲: 0
#   亞細亞: 0
#   亞東: 0
#   亞洲: 0
# Total Frequency: 0
# ----------------------------------------
# File: 鸭蛋岛探险记.txt
# Phrase Frequencies:
#   亞西亞大陸: 0
#   亞細亞洲: 0
#   亞西亞: 0
#   亞西亞洲: 0
#   亞細亞: 0
#   亞東: 0
#   亞洲: 0
# Total Frequency: 0
# ----------------------------------------
# Sum of Frequencies Across All Files:
#   亞西亞大陸: 1
#   亞細亞洲: 1
#   亞西亞: 1
#   亞西亞洲: 1
#   亞細亞: 2
#   亞東: 5
#   亞洲: 18
#
# Number of files containing at least one of the phrases: 9

# %%
from collections import Counter

# Initialize a dictionary to store phrase frequencies for each file
phrase_freq_dict = {}

# Define the specific phrases we care about
phrases_we_care = {"美國"}

# Define the tags we care about
tags_we_care = {'LOC', 'NORP', 'GPE'}

# Initialize a dictionary to store the sum of frequencies across all files
total_freq_across_files = {phrase: 0 for phrase in phrases_we_care}

# Counter to track the number of files containing at least one of the phrases
files_with_phrases = 0

# Iterate over each file in the results_dict
for file_name, file_data in results_dict.items():
    # Extract all_tags from the file data
    all_tags = file_data.get('all_tags', [])
    
    # Count the frequency of each specific phrase (only for tags in tags_we_care)
    phrase_counter = Counter(
        phrase for phrase, tag, _, _ in all_tags
        if tag in tags_we_care and phrase in phrases_we_care
    )
    
    # If the file contains at least one of the phrases, increment the counter
    if phrase_counter:
        files_with_phrases += 1
    
    # Store the phrase frequencies in the dictionary
    phrase_freq_dict[file_name] = {
        'phrase_freq': dict(phrase_counter),
        'total_freq': sum(phrase_counter.values())  # Sum of all phrase frequencies
    }
    
    # Update the total frequency across all files
    for phrase, freq in phrase_counter.items():
        total_freq_across_files[phrase] += freq

# Sort files by the total frequency of phrases (descending order)
sorted_files = sorted(phrase_freq_dict.items(), key=lambda x: x[1]['total_freq'], reverse=True)

# Print the results for each file
for file_name, data in sorted_files:
    print(f"File: {file_name}")
    print("Phrase Frequencies:")
    for phrase in phrases_we_care:
        freq = data['phrase_freq'].get(phrase, 0)  # Get frequency or 0 if phrase not found
        print(f"  {phrase}: {freq}")
    print(f"Total Frequency: {data['total_freq']}")
    print("-" * 40)  # Separator for readability

# Print the sum of frequencies across all files
print("Sum of Frequencies Across All Files:")
for phrase, total_freq in total_freq_across_files.items():
    print(f"  {phrase}: {total_freq}")

# Print the number of files containing at least one of the phrases
print(f"\nNumber of files containing at least one of the phrases: {files_with_phrases}")
# Out:
# File: 月球殖民地小說.txt
# Phrase Frequencies:
#   美國: 15
# Total Frequency: 15
# ----------------------------------------
# File: 狮子血.txt
# Phrase Frequencies:
#   美國: 3
# Total Frequency: 3
# ----------------------------------------
# File: 航海奇遇.txt
# Phrase Frequencies:
#   美國: 1
# Total Frequency: 1
# ----------------------------------------
# File: 记事小说虎口余生记.txt
# Phrase Frequencies:
#   美國: 1
# Total Frequency: 1
# ----------------------------------------
# File: 非洲探险记.txt
# Phrase Frequencies:
#   美國: 1
# Total Frequency: 1
# ----------------------------------------
# File: 革命党.txt
# Phrase Frequencies:
#   美國: 1
# Total Frequency: 1
# ----------------------------------------
# File: 魔窟.txt
# Phrase Frequencies:
#   美國: 1
# Total Frequency: 1
# ----------------------------------------
# File: 不可思议.txt
# Phrase Frequencies:
#   美國: 0
# Total Frequency: 0
# ----------------------------------------
# File: 中央亚非利加之蛮地探险.txt
# Phrase Frequencies:
#   美國: 0
# Total Frequency: 0
# ----------------------------------------
# File: 冒险夜行.txt
# Phrase Frequencies:
#   美國: 0
# Total Frequency: 0
# ----------------------------------------
# File: 冒险奇谈.txt
# Phrase Frequencies:
#   美國: 0
# Total Frequency: 0
# ----------------------------------------
# File: 冒险小说孤店村.txt
# Phrase Frequencies:
#   美國: 0
# Total Frequency: 0
# ----------------------------------------
# File: 冒险小说柏麦船长航海谈.txt
# Phrase Frequencies:
#   美國: 0
# Total Frequency: 0
# ----------------------------------------
# File: 冒险小说火山岛.txt
# Phrase Frequencies:
#   美國: 0
# Total Frequency: 0
# ----------------------------------------
# File: 冒险小说航海家儿.txt
# Phrase Frequencies:
#   美國: 0
# Total Frequency: 0
# ----------------------------------------
# File: 冒险小说金沙窟.txt
# Phrase Frequencies:
#   美國: 0
# Total Frequency: 0
# ----------------------------------------
# File: 冒险小说鬼域.txt
# Phrase Frequencies:
#   美國: 0
# Total Frequency: 0
# ----------------------------------------
# File: 冒险成功之商界伟人.txt
# Phrase Frequencies:
#   美國: 0
# Total Frequency: 0
# ----------------------------------------
# File: 冢中怪.txt
# Phrase Frequencies:
#   美國: 0
# Total Frequency: 0
# ----------------------------------------
# File: 北冰洋归客谈.txt
# Phrase Frequencies:
#   美國: 0
# Total Frequency: 0
# ----------------------------------------
# File: 南斐洲脱险记.txt
# Phrase Frequencies:
#   美國: 0
# Total Frequency: 0
# ----------------------------------------
# File: 叶兰.txt
# Phrase Frequencies:
#   美國: 0
# Total Frequency: 0
# ----------------------------------------
# File: 司宾洛.txt
# Phrase Frequencies:
#   美國: 0
# Total Frequency: 0
# ----------------------------------------
# File: 回风.txt
# Phrase Frequencies:
#   美國: 0
# Total Frequency: 0
# ----------------------------------------
# File: 地下都会与海底森林.txt
# Phrase Frequencies:
#   美國: 0
# Total Frequency: 0
# ----------------------------------------
# File: 女丈夫.txt
# Phrase Frequencies:
#   美國: 0
# Total Frequency: 0
# ----------------------------------------
# File: 小中华.txt
# Phrase Frequencies:
#   美國: 0
# Total Frequency: 0
# ----------------------------------------
# File: 岛国归婚记.txt
# Phrase Frequencies:
#   美國: 0
# Total Frequency: 0
# ----------------------------------------
# File: 弟.txt
# Phrase Frequencies:
#   美國: 0
# Total Frequency: 0
# ----------------------------------------
# File: 怪国探险记.txt
# Phrase Frequencies:
#   美國: 0
# Total Frequency: 0
# ----------------------------------------
# File: 探险英雄传.txt
# Phrase Frequencies:
#   美國: 0
# Total Frequency: 0
# ----------------------------------------
# File: 新殖民地仲尼島.txt
# Phrase Frequencies:
#   美國: 0
# Total Frequency: 0
# ----------------------------------------
# File: 树穴书.txt
# Phrase Frequencies:
#   美國: 0
# Total Frequency: 0
# ----------------------------------------
# File: 毒洲探险记.txt
# Phrase Frequencies:
#   美國: 0
# Total Frequency: 0
# ----------------------------------------
# File: 海上逸史.txt
# Phrase Frequencies:
#   美國: 0
# Total Frequency: 0
# ----------------------------------------
# File: 海底奇谈.txt
# Phrase Frequencies:
#   美國: 0
# Total Frequency: 0
# ----------------------------------------
# File: 渔父冒险记 冠万.txt
# Phrase Frequencies:
#   美國: 0
# Total Frequency: 0
# ----------------------------------------
# File: 渔父冒险记 孙明兴.txt
# Phrase Frequencies:
#   美國: 0
# Total Frequency: 0
# ----------------------------------------
# File: 渔父冒险记 林远隆.txt
# Phrase Frequencies:
#   美國: 0
# Total Frequency: 0
# ----------------------------------------
# File: 渔父冒险记 黄荣仙.txt
# Phrase Frequencies:
#   美國: 0
# Total Frequency: 0
# ----------------------------------------
# File: 滕半仙伝.txt
# Phrase Frequencies:
#   美國: 0
# Total Frequency: 0
# ----------------------------------------
# File: 片帆影.txt
# Phrase Frequencies:
#   美國: 0
# Total Frequency: 0
# ----------------------------------------
# File: 狼吻余生记.txt
# Phrase Frequencies:
#   美國: 0
# Total Frequency: 0
# ----------------------------------------
# File: 百斯笃殖民政策记.txt
# Phrase Frequencies:
#   美國: 0
# Total Frequency: 0
# ----------------------------------------
# File: 盗盗.txt
# Phrase Frequencies:
#   美國: 0
# Total Frequency: 0
# ----------------------------------------
# File: 破舟遇险记.txt
# Phrase Frequencies:
#   美國: 0
# Total Frequency: 0
# ----------------------------------------
# File: 磊落士官.txt
# Phrase Frequencies:
#   美國: 0
# Total Frequency: 0
# ----------------------------------------
# File: 穴居.txt
# Phrase Frequencies:
#   美國: 0
# Total Frequency: 0
# ----------------------------------------
# File: 空中岛.txt
# Phrase Frequencies:
#   美國: 0
# Total Frequency: 0
# ----------------------------------------
# File: 纪实冒险小说洞庭湖.txt
# Phrase Frequencies:
#   美國: 0
# Total Frequency: 0
# ----------------------------------------
# File: 航船盗.txt
# Phrase Frequencies:
#   美國: 0
# Total Frequency: 0
# ----------------------------------------
# File: 英男孝女记.txt
# Phrase Frequencies:
#   美國: 0
# Total Frequency: 0
# ----------------------------------------
# File: 荒岛孤踪.txt
# Phrase Frequencies:
#   美國: 0
# Total Frequency: 0
# ----------------------------------------
# File: 荒岛漂泊记.txt
# Phrase Frequencies:
#   美國: 0
# Total Frequency: 0
# ----------------------------------------
# File: 蛇虎斗.txt
# Phrase Frequencies:
#   美國: 0
# Total Frequency: 0
# ----------------------------------------
# File: 陆治斯南极探险事.txt
# Phrase Frequencies:
#   美國: 0
# Total Frequency: 0
# ----------------------------------------
# File: 青铜钱.txt
# Phrase Frequencies:
#   美國: 0
# Total Frequency: 0
# ----------------------------------------
# File: 驮轮御风记.txt
# Phrase Frequencies:
#   美國: 0
# Total Frequency: 0
# ----------------------------------------
# File: 鱼丽水历险记.txt
# Phrase Frequencies:
#   美國: 0
# Total Frequency: 0
# ----------------------------------------
# File: 鸭蛋岛探险记.txt
# Phrase Frequencies:
#   美國: 0
# Total Frequency: 0
# ----------------------------------------
# Sum of Frequencies Across All Files:
#   美國: 23
#
# Number of files containing at least one of the phrases: 7
